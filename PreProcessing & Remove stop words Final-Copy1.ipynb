# %%
# coding=utf-8
import pandas as pd
import csv  # Import csv
import tweepy
import re
import string
import nltk
import pandas as pd
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
import numpy as np
pd.set_option('display.max_colwidth',1000)

# %%
#col_list = ["ID", "FULL TEXT","CREATED AT","LABEL"]
#data = pd.read_csv('get_tweets.csv', usecols=col_list)
#data.columns = ['ID','FULL_TEXT','CREATED_AT','LABEL']
#print(data)

# %%
################ working code#############################
#data = pd.read_csv('TweetsWithLabels', header = None, encoding='utf-8')
#data.columns = ['ID','User','FULL_TEXT','CREATED_AT','LABEL']
#data = data.dropna()
#data.head()

# %%
#!/usr/bin/env python
# -*- coding:utf-8 -*-

import codecs
data = pd.read_csv('aa.csv', header = None, encoding='utf-8', engine='python')
data.columns = ['ID','User','FULL_TEXT','CREATED_AT','LIKE COUNT','FOLLOWERS COUNT','LABEL']
data = data.dropna()
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-26-5b565fe4eaf5> in <module>
#       3
#       4 import codecs
# ----> 5 data = pd.read_csv('aa.csv', header = None, encoding='utf-8', engine='python')
#       6 data.columns = ['ID','User','FULL_TEXT','CREATED_AT','LIKE COUNT','FOLLOWERS COUNT','LABEL']
#       7 data = data.dropna()
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2556     def read(self, rows=None):
#    2557         try:
# -> 2558             content = self._get_lines(rows)
#    2559         except StopIteration:
#    2560             if self._first_chunk:
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _get_lines(self, rows)
#    3303
#    3304                         while True:
# -> 3305                             new_row = self._next_iter_line(row_num=self.pos + rows + 1)
#    3306                             rows += 1
#    3307
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    3014         """
#    3015         try:
# -> 3016             return next(self.data)
#    3017         except csv.Error as e:
#    3018             if self.warn_bad_lines or self.error_bad_lines:
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe0 in position 5423: invalid continuation byte

# %%
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    regex = re.compile(u'[^\u0D80-\u0DFF]', re.UNICODE)
    tokens = [regex.sub('', w) for w in tokens]
    tokens = [c for c in tokens if c not in string.punctuation]
    return tokens

# %%
data['cleaned_msg'] = data['FULL_TEXT'].apply(lambda x: clean_text(x))
data.head()
# Out:
#     ID      User  \
# 2  0.0  1.42E+18
# 3  1.0  1.42E+18
# 4  2.0  1.42E+18
# 5  3.0  1.42E+18
# 6  4.0  1.42E+18
#
#                                                                                                                                                                 FULL_TEXT  \
# 2                                                          @Srihandalk @kajuwattha හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්‍යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ. ?
# 3                                                                 @GotabayaR ද්විපාර්ශවික එකඟතාව පරිදි, ජන ජීවිත සහ සෞඛ්‍යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා ?
# 4                                                   @FCDOGovUK @UKinSriLanka කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි?
# 5      @WHOSriLanka @WHOSEARO @UNSriLanka @MoH_SriLanka @HPBSriLanka @DMRCASriLanka @ACJUNEWS @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුර?
# 6  @WHOSriLanka @UNSriLanka @WHOSEARO @WHO @MoH_SriLanka @HPBSriLanka @RajapaksaNamal @MCND_LKA @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට ය?
#
#         CREATED_AT LIKE COUNT FOLLOWERS COUNT     LABEL  \
# 2   7/29/2021 2:40          1            1433     Other
# 3  7/27/2021 10:40         10           13898  Politics
# 4  7/25/2021 20:56          0              87     Other
# 5  7/25/2021 20:53          0              87     Other
# 6  7/25/2021 20:52          1              87     Other
#
#                                                                                                cleaned_msg
# 2          [හාමුදුරුවරුන්ගේ, සහ, සියලූම, පූජකයන්ගේ, මානසික, සෞඛ්යය, ගැන, සොයා, බැලීමේ, වැඩ, පිලිවලක්, ඕනේ]
# 3  [ද්විපාර්ශවික, එකඟතාව, පරිදි, ජන, ජීවිත, සහ, සෞඛ්යය, මනාව, ආරක්ෂා, කරමින්, හැකි, ඉක්මණින්, ආර්ථිකය, හා]
# 4          [කරැනාකර, චිනයේ, නිෂ්පාදිත, එන්නත, ලබාගත්, පුද්ගලයන්, හට, යුරෝපීය, රට, වලට, විසා, නිකුත්, නොකි]
# 5                                           [කරැනාකර, චිනයේ, නිෂ්පාදිත, එන්නත, ලබාගත්, පුද්ගලයන්, හට, යුර]
# 6                                             [කරැනාකර, චිනයේ, නිෂ්පාදිත, එන්නත, ලබාගත්, පුද්ගලයන්, හට, ය]

# %%
#######################c Remove Stop words Method 1: Remove stop words  #########################################

# %%
cleaned_data = data['cleaned_msg']
wli = []
for l in cleaned_data:
    l = l.split()
    
    for w in l:
        wli.append(w)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-097e27c29005> in <module>
#       2 wli = []
#       3 for l in cleaned_data:
# ----> 4     l = l.split()
#       5
#       6     for w in l:
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# create word dictionary word and word count
wli.sort()
wd = {} 
for w in wli:
    wd[w] = wli.count(w)
    
print('\n{:^8}{:^8}'.format('word','count'))
for w in wd:
    print('{:^8}{:^8}'.format(w,wd[w]))
    
print("")

# %%
stopword = []
for w in wd:
    if(wd[w]>10):
        stopword.append(w)
print(stopword)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7d68e4f839a8> in <module>
#       1 stopword = []
# ----> 2 for w in wd:
#       3     if(wd[w]>10):
#       4         stopword.append(w)
#       5 print(stopword)
#
# NameError: name 'wd' is not defined

# %%
# def clean_text(text):
#     tokens = nltk.word_tokenize(text)
#     tokens = " ".join([word for word in tokens if word not in stopword])
#     return tokens

# %%
# data['remove_stopwords'] = data['cleaned_msg'].apply(lambda x: clean_text(x))
# data.head()

# %%
############################ Stop Word removing Method 2 - using predefined stop words ####################################

# %%
stopwordsreader = open('StopWords', 'r', encoding='utf-8')
reader = csv.reader(stopwordsreader)

swords = []
for row in reader:
    swords.append(row[0])
print(swords)
# Out:
# ['සහ', 'සමග', 'සමඟ', 'අහා', 'ආහ්', 'ආ', 'ඕහෝ', 'අනේ', 'අඳෝ', 'අපොයි', 'අපෝ', 'අයියෝ', 'ආයි', 'ඌයි', 'චී', 'චිහ්', 'චික්', 'හෝ\u200d', 'දෝ', 'දෝහෝ', 'මෙන්', 'සේ', 'වැනි', 'බඳු', 'වන්', 'අයුරු', 'අයුරින්', 'ලෙස', 'වැඩි', 'ශ්\u200dරී', 'හා', 'ය', 'නිසා', 'නිසාවෙන්', 'බවට', 'බව', 'බවෙන්', 'නම්', 'වැඩි', 'සිට', 'දී', 'මහා', 'මහ', 'පමණ', 'පමණින්', 'පමන', 'වන', 'විට', 'විටින්', 'මේ', 'මෙලෙස', 'මෙයින්', 'ඇති', 'ලෙස', 'සිදු', 'වශයෙන්', 'යන', 'සඳහා', 'මගින්', 'හෝ\u200d', 'ඉතා', 'ඒ', 'එම', 'ද', 'අතර', 'විසින්', 'සමග', 'පිළිබඳව', 'පිළිබඳ', 'තුළ', 'බව', 'වැනි', 'මහ', 'මෙම', 'මෙහි', 'මේ', 'වෙත', 'වෙතින්', 'වෙතට', 'වෙනුවෙන්', 'වෙනුවට', 'වෙන', 'ගැන', 'නෑ', 'අනුව', 'නව', 'පිළිබඳ', 'විශේෂ', 'දැනට', 'එහෙන්', 'මෙහෙන්', 'එහේ', 'මෙහේ', 'ම', 'තවත්', 'තව ', 'සහ', 'දක්වා', 'ට', 'ගේ', 'එ', 'ක', 'ක්', 'බවත්', 'බවද', 'මත', 'ඇතුලු', 'ඇතුළු', 'මෙසේ', 'වඩා', 'වඩාත්ම', 'නිති', 'නිතිත්', 'නිතොර', 'නිතර', 'ඉක්බිති', 'දැන්', 'යලි', 'පුන', 'ඉතින්', 'සිට', 'සිටන්', 'පටන්', 'තෙක්', 'දක්වා', 'සා', 'තාක්', 'තුවක්', 'පවා', 'ද', 'හෝ\u200d', 'වත්', 'විනා', 'හැර', 'මිස', 'මුත්', 'කිම', 'කිම්', 'ඇයි', 'මන්ද', 'හෙවත්', 'නොහොත්', 'පතා', 'පාසා', 'ගානෙ', 'තව', 'ඉතා', 'බොහෝ', 'වහා', 'සෙද', 'සැනින්', 'හනික', 'එම්බා', 'එම්බල', 'බොල', 'නම්', 'වනාහි', 'කලී', 'ඉඳුරා', 'අන්න', 'ඔන්න', 'මෙන්න', 'උදෙසා', 'පිණිස', 'සඳහා', 'අරබයා', 'නිසා', 'එනිසා', 'එබැවින්', 'බැවින්', 'හෙයින්', 'සේක්', 'සේක', 'ගැන', 'අනුව', 'පරිදි', 'විට', 'තෙක්', 'මෙතෙක්', 'මේතාක්', 'තුරු', 'තුරා', 'තුරාවට', 'තුලින්', 'නමුත්', 'එනමුත්', 'වස්', 'මෙන්', 'ලෙස', 'පරිදි', 'එහෙත්']

# %%
def remove_stop_words(text):
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in swords]
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
data['remove_stopword'] = data['cleaned_msg'].apply(lambda x: remove_stop_words(x))
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-849db6abedfb> in <module>
# ----> 1 data['remove_stopword'] = data['cleaned_msg'].apply(lambda x: remove_stop_words(x))
#       2 data.head()
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-15-849db6abedfb> in <lambda>(x)
# ----> 1 data['remove_stopword'] = data['cleaned_msg'].apply(lambda x: remove_stop_words(x))
#       2 data.head()
#
# <ipython-input-14-c567b05b5cec> in remove_stop_words(text)
#       1 def remove_stop_words(text):
# ----> 2     tokens = nltk.word_tokenize(text)
#       3     tokens = [word for word in tokens if word not in swords]
#       4     tokens = " ".join([c for c in tokens if c not in string.punctuation])
#       5     return tokens
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     128     :type preserve_line: bool
#     129     """
# --> 130     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     131     return [
#     132         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     106     """
#     107     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 108     return tokenizer.tokenize(text)
#     109
#     110
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1272         Given a text, returns a list of the sentences in that text.
#    1273         """
# -> 1274         return list(self.sentences_from_text(text, realign_boundaries))
#    1275
#    1276     def debug_decisions(self, text):
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1326         follows the period.
#    1327         """
# -> 1328         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1329
#    1330     def _slices_from_text(self, text):
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1326         follows the period.
#    1327         """
# -> 1328         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1329
#    1330     def _slices_from_text(self, text):
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1316         if realign_boundaries:
#    1317             slices = self._realign_boundaries(text, slices)
# -> 1318         for sl in slices:
#    1319             yield (sl.start, sl.stop)
#    1320
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1357         """
#    1358         realign = 0
# -> 1359         for sl1, sl2 in _pair_iter(slices):
#    1360             sl1 = slice(sl1.start + realign, sl1.stop)
#    1361             if not sl2:
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     314     it = iter(it)
#     315     try:
# --> 316         prev = next(it)
#     317     except StopIteration:
#     318         return
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1330     def _slices_from_text(self, text):
#    1331         last_break = 0
# -> 1332         for match in self._lang_vars.period_context_re().finditer(text):
#    1333             context = match.group() + match.group("after_tok")
#    1334             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object

# %%
########################################## Stemming ##################################################

# %%
stem_dict = open("stem_dictionary.txt", "r", encoding='utf-8')
stem_dict = map(lambda s: s.strip(), stem_dict)

stem_dictionary = {}

for s in stem_dict:
    s = s.split("\t")
    stem_dictionary[s[0]] = s[1]

# %%
def stemming_words(text):
    tokens = nltk.word_tokenize(text)
    for k, v in enumerate(tokens):
        tokens[k] = stem_dictionary.get(v, v)
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
data['stemming_words'] = data['remove_stopword'].apply(lambda x: stemming_words(x))
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'remove_stopword'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4860758b4ce5> in <module>
# ----> 1 data['stemming_words'] = data['remove_stopword'].apply(lambda x: stemming_words(x))
#       2 data.head()
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'remove_stopword'

# %%
######################### Remove Duplicates from dataset #################

# %%
data.drop_duplicates(subset='stemming_words',keep='first',inplace = True)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4e11bd638020> in <module>
# ----> 1 data.drop_duplicates(subset='stemming_words',keep='first',inplace = True)
#       2 data.head()
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5110
#    5111         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5112         duplicated = self.duplicated(subset, keep=keep)
#    5113
#    5114         result = self[-duplicated]
#
# c:\users\chandima samarakoon\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5246         diff = Index(subset).difference(self.columns)
#    5247         if not diff.empty:
# -> 5248             raise KeyError(diff)
#    5249
#    5250         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['stemming_words'], dtype='object')

# %%
df = pd.DataFrame(data, columns= ['User', 'CREATED_AT','LABEL','stemming_words','LIKE COUNT','FOLLOWERS COUNT'])
df.to_csv("FinalListPreprocessedData.csv")

# %%
#################################Linear regression classification #######################################

# %%
data['LABEL'].value_counts()
# Out:
# Other                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# Politics                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# Crime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# Sport                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# Entertainment                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# <bound method Status.retweets of Status(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'created_at': 'Sat Sep 04 06:58:39 +0000 2021', 'id': 1434048244393381891, 'id_str': '1434048244393381891', 'full_text': 'කොරෝනා රෝගීන් වෛද්\u200dය උපදෙස්වලින් තොරව විවිධ ඖෂධ භාවිතයෙන් වළකින්න - Read More &gt;&gt;&gt; https://t.co/L9tJMs4Q1O #LKA #SriLanka https://t.co/JDuqzyp2zw', 'truncated': False, 'display_text_range': [0, 129], 'entities': {'hashtags': [{'text': 'LKA', 'indices': [115, 119]}, {'text': 'SriLanka', 'indices': [120, 129]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/L9tJMs4Q1O', 'expanded_url': 'https://www.itnnews.lk/2021/09/04/360180/', 'display_url': 'itnnews.lk/2021/09/04/360…', 'indices': [91, 114]}], 'media': [{'id': 1434048242778624000, 'id_str': '1434048242778624000', 'indices': [130, 153], 'media_url': 'http://pbs.twimg.com/media/E-bDR2WX0AAYfJd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-bDR2WX0AAYfJd.jpg', 'url': 'https://t.co/JDuqzyp2zw', 'display_url': 'pic.twitter.com/JDuqzyp2zw', 'expanded_url': 'https://twitter.com/itnnewslk/status/1434048244393381891/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 355, 'resize': 'fit'}, 'large': {'w': 800, 'h': 418, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 418, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1434048242778624000, 'id_str': '1434048242778624000', 'indices': [130, 153], 'media_url': 'http://pbs.twimg.com/media/E-bDR2WX0AAYfJd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-bDR2WX0AAYfJd.jpg', 'url': 'https://t.co/JDuqzyp2zw', 'display_url': 'pic.twitter.com/JDuqzyp2zw', 'expanded_url': 'https://twitter.com/itnnewslk/status/1434048244393381891/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 355, 'resize': 'fit'}, 'large': {'w': 800, 'h': 418, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 418, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'si', 'result_type': 'recent'}, 'source': '<a href="http://www.itnnews.lk" rel="nofollow">ITN News Auto Share</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3219290929, 'id_str': '3219290929', 'name': 'ITN News', 'screen_name': 'itnnewslk', 'location': 'Sri Lanka', 'description': 'Welcome to ITN News on Twitter. News, Views, Reviews, Interviews and a whole range of intriguing stories on various categories.', 'url': 'https://t.co/eMnUnF6FYv', 'entities': {'url': {'urls': [{'url': 'https://t.co/eMnUnF6FYv', 'expanded_url': 'http://www.itnnews.lk', 'display_url': 'itnnews.lk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2233, 'friends_count': 4, 'listed_count': 11, 'created_at': 'Mon May 18 10:51:45 +0000 2015', 'favourites_count': 10, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 63567, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1344950243662712832/bs1Addvp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1344950243662712832/bs1Addvp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3219290929/1464588775', 'profile_link_color': 'B40404', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': ...
# <bound method Status.retweets of Status(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'created_at': 'Sun Sep 05 11:30:58 +0000 2021', 'id': 1434479161985351685, 'id_str': '1434479161985351685', 'full_text': 'යාපනය අච්චුවේලි නාවට්කාඩු ප්\u200dරදේශයේ පැවති අවමංගල්\u200dය උත්සව අවස්ථාවකට සෞඛ්\u200dය නීති කඩකරමින් 600 කට අධික පිරිසක් සහභාගී වීම හේතුවෙන් අදාල පිරිස විසුරුවා හැරීමට පොලිස් නිලධාරීන් පියවර ගත්හ.\n\nපසුගිය 02 වනදානාවට්කාඩු ප්\u200dරදේශයේ පිහිටි කුඹුරක සීසාමින් සිටි 40\n\nhttps://t.co/ysozjTDw6L https://t.co/Akq1uyIZDj', 'truncated': False, 'display_text_range': [0, 275], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ysozjTDw6L', 'expanded_url': 'https://www.lankaplusnews.com/%e0%b6%9a%e0%b7%9c%e0%b6%bb%e0%b7%9d%e0%b6%b1%e0%b7%8f-%e0%b6%9a%e0%b7%90%e0%b6%bd%e0%b7%9a/2021/09/05/', 'display_url': 'lankaplusnews.com/%e0%b6%9a%e0%b…', 'indices': [252, 275]}], 'media': [{'id': 1434479160471216129, 'id_str': '1434479160471216129', 'indices': [276, 299], 'media_url': 'http://pbs.twimg.com/media/E-hLMj2WYAExPwX.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-hLMj2WYAExPwX.jpg', 'url': 'https://t.co/Akq1uyIZDj', 'display_url': 'pic.twitter.com/Akq1uyIZDj', 'expanded_url': 'https://twitter.com/lankaplus_news/status/1434479161985351685/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 355, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 800, 'h': 418, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 418, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1434479160471216129, 'id_str': '1434479160471216129', 'indices': [276, 299], 'media_url': 'http://pbs.twimg.com/media/E-hLMj2WYAExPwX.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-hLMj2WYAExPwX.jpg', 'url': 'https://t.co/Akq1uyIZDj', 'display_url': 'pic.twitter.com/Akq1uyIZDj', 'expanded_url': 'https://twitter.com/lankaplus_news/status/1434479161985351685/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 680, 'h': 355, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 800, 'h': 418, 'resize': 'fit'}, 'medium': {'w': 800, 'h': 418, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'si', 'result_type': 'recent'}, 'source': '<a href="https://www.blog2social.com" rel="nofollow">Blog2Social APP</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1268864031944847360, 'id_str': '1268864031944847360', 'name': 'Lanka Plus News', 'screen_name': 'lankaplus_news', 'location': 'Harrow, London', 'description': 'Connect with your Community…!', 'url': 'https://t.co/p6YonI87kK', 'entities': {'url': {'urls': [{'url': 'https://t.co/p6YonI87kK', 'expanded_url': 'http://www.lankaplusnews.com/', 'display_url': 'lankaplusnews.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 116, 'friends_count': 633, 'listed_count': 0, 'created_at': 'Fri Jun 05 11:17:06 +0000 2020', 'favourites_count': 8, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4903, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1284129789029146624/QxViLJGp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284129789029146624/QxViLJGp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1268864031944847360/1591356270', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_pro ...
# <bound method Status.retweets of Status(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'created_at': 'Sun Sep 05 17:31:49 +0000 2021', 'id': 1434569975289847814, 'id_str': '1434569975289847814', 'full_text': 'ඉරිදා කොරෝනා මරණ 189 යි ආසාදිතයින් 3308 යි\n\nඉරිදා කොරෝනා මරණ 189 යි ආසාදිතයින් 3308 යි https://t.co/ZApBLMy2gL', 'truncated': False, 'display_text_range': [0, 110], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ZApBLMy2gL', 'expanded_url': 'https://ift.tt/3BO6IQ7', 'display_url': 'ift.tt/3BO6IQ7', 'indices': [87, 110]}]}, 'metadata': {'iso_language_code': 'si', 'result_type': 'recent'}, 'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 163797399, 'id_str': '163797399', 'name': 'Gossip Lanka News', 'screen_name': 'gossiplanka', 'location': 'Colombo', 'description': 'Underground News from Sri Lanka', 'url': 'http://t.co/wmcuQCREEk', 'entities': {'url': {'urls': [{'url': 'http://t.co/wmcuQCREEk', 'expanded_url': 'http://www.gossiplankanews.com', 'display_url': 'gossiplankanews.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 7416, 'friends_count': 4, 'listed_count': 25, 'created_at': 'Wed Jul 07 08:53:27 +0000 2010', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 35038, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0E67A6', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/447641429485961216/yyboSDeb_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/447641429485961216/yyboSDeb_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/163797399/1395561180', 'profile_link_color': '1A7FA3', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'si'}, created_at=datetime.datetime(2021, 9, 5, 17, 31, 49), id=1434569975289847814, id_str='1434569975289847814', full_text='ඉරිදා කොරෝනා මරණ 189 යි ආසාදිතයින් 3308 යි\n\nඉරිදා කොරෝනා මරණ 189 යි ආසාදිතයින් 3308 යි https://t.co/ZApBLMy2gL', truncated=False, display_text_range=[0, 110], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/ZApBLMy2gL', 'expanded_url': 'https://ift.tt/3BO6IQ7', 'display_url': 'ift.tt/3BO6IQ7', 'indices': [87, 110]}]}, metadata={'iso_language_code': 'si', 'result_type': 'recent'}, source='IFTTT', source_url='https://ifttt.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'id': 163797399, 'id_str': '163797399', 'name': 'Gossip Lanka News', 'screen_name': 'gossiplanka', 'location': 'Colombo', 'description': 'Underground News from Sri Lanka', 'url': 'http://t.co/wmcuQCREEk', 'entities': {'url': {'urls': [{'url': 'http://t.co/wmcuQCREEk', 'expanded_url': 'http://www.gossiplankanews.com', 'display_url': 'gossiplankan ...
# <bound method Status.retweets of Status(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'created_at': 'Mon Sep 06 15:06:36 +0000 2021', 'id': 1434895817312141312, 'id_str': '1434895817312141312', 'full_text': 'ලෝකේ රටවල් රැසක් භාවිතා කරන ලබාදෙන ලෝක සෞඛ්\u200dය සංවිධානය විසින් අනුමත කරනලද පරීක්ෂණ මගින් තහවුරු කරනලද කොවිඩ් එන්නත් ගැන මේ වෛද්\u200dයවරයා අසත්\u200dය සමාජගත කරමින් සිටියි මොහු කොරෝනා සුවකල හැකියයි කියමින් කරලක් විකුණමින් සිටියි බැලු බැල්මට පෙනවා ඔහුගේ අවශ්\u200dයතාවය නිෂ්පාදනය විකුණා ගැනීම කියල https://t.co/ukReROc0WJ', 'truncated': False, 'display_text_range': [0, 280], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1434895813721739266, 'id_str': '1434895813721739266', 'indices': [281, 304], 'media_url': 'http://pbs.twimg.com/media/E-nGI-KUUAIDJet.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-nGI-KUUAIDJet.jpg', 'url': 'https://t.co/ukReROc0WJ', 'display_url': 'pic.twitter.com/ukReROc0WJ', 'expanded_url': 'https://twitter.com/sameerawgp/status/1434895817312141312/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1434895813721739266, 'id_str': '1434895813721739266', 'indices': [281, 304], 'media_url': 'http://pbs.twimg.com/media/E-nGI-KUUAIDJet.jpg', 'media_url_https': 'https://pbs.twimg.com/media/E-nGI-KUUAIDJet.jpg', 'url': 'https://t.co/ukReROc0WJ', 'display_url': 'pic.twitter.com/ukReROc0WJ', 'expanded_url': 'https://twitter.com/sameerawgp/status/1434895817312141312/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'si', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3028799013, 'id_str': '3028799013', 'name': 'Sameera Perera', 'screen_name': 'sameerawgp', 'location': 'Los Angeles, CA', 'description': 'I am a Political explorer also studying business economics and accounting at Cal state Dominguez Hills CSUDH', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 856, 'friends_count': 38, 'listed_count': 1, 'created_at': 'Tue Feb 10 21:29:23 +0000 2015', 'favourites_count': 545, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2218, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1121259156181094400/bhAVnEH8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1121259156181094400/bhAVnEH8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3028799013/1605150197', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'fa ...
# <bound method Status.retweets of Status(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'created_at': 'Wed Sep 08 09:59:25 +0000 2021', 'id': 1435543286517805058, 'id_str': '1435543286517805058', 'full_text': 'ඊයේ කොරෝනා මරණ 184 ක්, ආසාදිතයෝ 2564 දෙනෙක් - SLBC News ( Sinhala ) https://t.co/RwVbSvSUq6 via @SLBCnewslk', 'truncated': False, 'display_text_range': [0, 107], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SLBCnewslk', 'name': 'SLBC News', 'id': 4099101253, 'id_str': '4099101253', 'indices': [96, 107]}], 'urls': [{'url': 'https://t.co/RwVbSvSUq6', 'expanded_url': 'http://sinhala.newsslbc.lk/?p=74704', 'display_url': 'sinhala.newsslbc.lk/?p=74704', 'indices': [68, 91]}]}, 'metadata': {'iso_language_code': 'si', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4099101253, 'id_str': '4099101253', 'name': 'SLBC News', 'screen_name': 'SLBCnewslk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 114, 'friends_count': 211, 'listed_count': 0, 'created_at': 'Mon Nov 02 06:38:04 +0000 2015', 'favourites_count': 44, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8783, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/989773825322594306/JwHbiwVg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989773825322594306/JwHbiwVg_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4099101253/1590990313', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'si'}, created_at=datetime.datetime(2021, 9, 8, 9, 59, 25), id=1435543286517805058, id_str='1435543286517805058', full_text='ඊයේ කොරෝනා මරණ 184 ක්, ආසාදිතයෝ 2564 දෙනෙක් - SLBC News ( Sinhala ) https://t.co/RwVbSvSUq6 via @SLBCnewslk', truncated=False, display_text_range=[0, 107], entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'SLBCnewslk', 'name': 'SLBC News', 'id': 4099101253, 'id_str': '4099101253', 'indices': [96, 107]}], 'urls': [{'url': 'https://t.co/RwVbSvSUq6', 'expanded_url': 'http://sinhala.newsslbc.lk/?p=74704', 'display_url': 'sinhala.newsslbc.lk/?p=74704', 'indices': [68, 91]}]}, metadata={'iso_language_code': 'si', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001CB3ABD4A90>, _json={'id': 4099101253, 'id_str': '4099101253', 'name': 'SLBC News', 'screen_name': 'SLBCnewslk', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 114, 'friends_count': 211, 'listed_count': 0, 'cre ...
# Name: LABEL, Length: 489, dtype: int64

# %%
data.shape
# Out:
# (1017, 10)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv1 = CountVectorizer()
x = cv1.fit_transform(data['stemming_words'])

# %%
print(x.shape)
# Out:
# (1017, 1512)

# %%
x[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,data['LABEL'], test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score # mectric that use

# %%
#training
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
review = 'අන්තර්ජාලය ඔස්සේ අළෙවි වූ බාලවයස්කාර දැරිය අපයෝජනය කිරීමේ කාන්තා'
commenttype = model.predict(cv1.transform([review]))[0]
if commenttype=='Crime':
    print('Crime Comment')
elif commenttype=='Sport':
     print('Sport Comment')
else:
    print('Other Comment')
# Out:
# Crime Comment

# %%
csvfile = open('FinalListPreprocessedData.csv', encoding="utf-8")
lines= len(csvfile.readlines())
print(lines)
# Out:
# 1018
