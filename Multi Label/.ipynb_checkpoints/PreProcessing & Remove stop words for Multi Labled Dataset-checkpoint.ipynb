# %%
# coding=utf-8
import pandas as pd
import csv  # Import csv
import tweepy
import re
import string
import nltk
import pandas as pd
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
import numpy as np
pd.set_option('display.max_colwidth',1000)

# %%
#!/usr/bin/env python
# -*- coding:utf-8 -*-

import codecs
data = pd.read_csv('Multi label dataset.csv', header = None, encoding='utf-8', engine='python')
data.columns = ['ID','User','FULL_TEXT','CREATED_AT','LIKE COUNT','FOLLOWERS COUNT','POLITICS','CRIME','ENTERTAINMENT','SPORT','OTHER']
data = data.dropna()
data.head()

# %%
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    regex = re.compile(u'[^\u0D80-\u0DFF]', re.UNICODE)
    tokens = [regex.sub('', w) for w in tokens]
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
data['cleaned_msg'] = data['FULL_TEXT'].apply(lambda x: clean_text(x))
data.head()
# Out:
#     ID      User  \
# 2  0.0  1.42E+18
# 3  1.0  1.42E+18
# 4  2.0  1.42E+18
# 5  3.0  1.42E+18
# 6  4.0  1.42E+18
#
#                                                                                                                                                                 FULL_TEXT  \
# 2                                                          @Srihandalk @kajuwattha හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්‍යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ. ?
# 3                                                                 @GotabayaR ද්විපාර්ශවික එකඟතාව පරිදි, ජන ජීවිත සහ සෞඛ්‍යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා ?
# 4                                                   @FCDOGovUK @UKinSriLanka කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි?
# 5      @WHOSriLanka @WHOSEARO @UNSriLanka @MoH_SriLanka @HPBSriLanka @DMRCASriLanka @ACJUNEWS @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුර?
# 6  @WHOSriLanka @UNSriLanka @WHOSEARO @WHO @MoH_SriLanka @HPBSriLanka @RajapaksaNamal @MCND_LKA @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට ය?
#
#         CREATED_AT LIKE COUNT FOLLOWERS COUNT     LABEL  \
# 2   7/29/2021 2:40          1            1433     Other
# 3  7/27/2021 10:40         10           13898  Politics
# 4  7/25/2021 20:56          0              87     Other
# 5  7/25/2021 20:53          0              87     Other
# 6  7/25/2021 20:52          1              87     Other
#
#                                                                                 cleaned_msg
# 2        හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3  ද්විපාර්ශවික එකඟතාව පරිදි ජන ජීවිත සහ සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා
# 4         කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                                     කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                       කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට ය

# %%
#######################c Remove Stop words Method 1: Remove stop words  #########################################

# %%
cleaned_data = data['cleaned_msg']
wli = []
for l in cleaned_data:
    l = l.split()
    
    for w in l:
        wli.append(w)

# %%
# create word dictionary word and word count
wli.sort()
wd = {} 
for w in wli:
    wd[w] = wli.count(w)
    
print('\n{:^8}{:^8}'.format('word','count'))
for w in wd:
    print('{:^8}{:^8}'.format(w,wd[w]))
    
print("")
# Out:
#   word   count
#    අ       1
#   අංක      1
#  අංගම්     1
# අංගම්පොර   1
#  අංගයක්    2
#   අංචී     1
#  අංශයේ     2
#  අංශවල     1
# අංශවලින්   1
#  අක්කේ     1
# අක්රමිකතා   3
#   අකිල     1
#  අකුරු     5
#   අගදී     1
# අගනුවරට    1
#  අගමැටි    1
#  අගමැති    3
#   අගය      2
# අග්රාමාත්ය   16
# අග්රාමාත්යතුමාගේ   1
# අග්රාමාත්යවරයා   1
# අගොස්තු    1
# අගෝස්තු    2
# අඟහරුවාදා   1
#  අජිත්     1
#    අට      1
#  අටකින්    1
# අඩංගුවට    1
#   අඩු      16
# අඩුගානේ    1
#   අඩුම     1
#   අඩුව     1
# අඩුවෙන්    1
#    අත      1
#   අතර      35
#   අතරට     2
#  අතරින්    1
#   අත්      1
# අත්අඩංගුවට   17
#  අත්පත්    5
#  අත්විද    1
# අත්විදිය   1
#  අත්සන්    1
# අත්හිටුවා   1
#  අතිගරු    2
#  අතින්     1
# අතිවිශේෂ   1
#  අතීතයේ    1
# අතුරින්    2
# අතුරුදහන්   1
#    අද      65
#   අදට      1
#   අදත්     1
#   අදයි     1
#  අදහස්     3
# අද්දැකීම්   1
#   අදාල     2
#  අදාලව     2
#   අදාළ     2
#  අදිටන     1
#   අදින     1
# අදින්නෙම   1
# අධ්යක්ෂ    11
# අධ්යක්ෂක   1
# අධ්යපනය    1
# අධ්යාපන    3
# අධ්යාපනය   2
# අධ්යාපනයට   2
#   අධික     3
#  අධිකරණ    9
# අධිකරණය    4
# අධිකරණයකට   2
# අධිකරණයට   3
# අධිකරණයෙන්   2
# අධිරාජ්යවාදීන්ගේ   1
# අනතුරකට    1
# අනතුරක්    1
#  අනතුරු    1
# අනතුරුව    2
# අනතුරුවය   1
#   අන්      1
# අන්තර්ජාතික   1
# අන්තර්ජාල   1
# අන්තවාදීන්ටත්   1
#  අන්තිම    1
# අන්යෝන්ය   2
#  අනාගත     3
# අනාගතපරපුරවෙනුවෙන්පරිසරයආරක්ෂාකරනවාඅමාත්   1
#  අනාචාර    1
# අනාවරණය    2
# අනාවරණයක්   1
#   අනික     1
#  අනිත්     1
# අනිවාර්යයෙන්   1
# අනුග්රහයක්   1
# අනුන්ගෙන්   1
#   අනුර     3
#  අනුරල     1
#   අනුව     14
#   අනූව     1
#  අනෙක්     1
# අනෙකුත්    1
#   අනේ      1
# අඳින්නේ    1
#   අපගේ     5
#  අපචාර     1
# අපයෝජනයට   1
#  අපරාදෙ    1
#  අපරාදේ    1
#  අපරාධ     40
# අපරාධකරුවන්ට   1
# අපරාධයක්   1
# අපරාධයේ    1
# අපරාධවලට   1
# අපවාදයක්   1
#   අප්      1
#   අපි      13
#   අපිට     8
#  අපිත්     2
#   අපිම     2
#   අපෙ      1
#   අපේ      16
# අපේක්ෂකයන්ට   1
# අපේක්ෂා    1
#    අබ      1
# අබ්දුල්    1
# අබිරහස්    6
# අබුඩාබි    1
# අබේකෝන්    2
# අබේසිංහ    2
#  අභිනව     1
# අභිනවයෙන්   1
# අභිමානි    1
#  අභියෝග    1
#  අභිශේක    1
#   අමතක     2
#  අමතරව     1
#   අමතා     1
#  අමරපාල    1
#  අමරසේන    1
# අමරසේනට    1
# අම්පාරෙ    1
#  අම්මා     2
#  අමාත්ය    24
# අමාත්යංශයේ   1
# අමාත්යතුමා   1
# අමාත්යවරයා   1
# අමාත්යවරයාගේ   1
# අමාත්යාංශය   6
# අමාත්යාංශයෙන්   1
# අමාත්යාංශේ   1
# අමාරැයි    2
#   අමු      1
# අමුණුගම    1
#  අමුතු     3
# අමුතුවෙන්   1
# අමෙරිකානු   1
#    අය      6
#   අයකු     1
#   අයට      1
#  අයටත්     2
#   අයත්     1
# අයිතිකාරයා   1
# අයිතිකාරයො   1
# අයිතියට    3
# අයුරින්    1
#  අයෙක්     2
#  අයෙකු     1
#    අර      6
#   අරං      1
# අරගලයටජයවේවා   1
#  අරගෙන     1
#   අරන්     1
# අරන්දෙන්න   1
#  අරමුණ     2
#  අරලිය     1
# අරලියගහ    3
# අරවින්ද    1
#   අර්ත     1
# අර්බුදය    1
#  අරාබි     6
#   අරින     1
#   අරුණ     1
#  අරුණි     1
# අරුන්දික   1
# අරුන්දිකට   2
#    අල      1
# අලහප්පෙරුම   1
#  අල්ලන්    1
# අල්ලන්න    1
# අල්ලන්නෙ   2
#  අල්ලයි    1
#  අල්ලස්    5
#  අල්ලා     1
# අලිසබ්රි   1
#  අලුත්     5
#  අලුයම     1
#  අලෙවි     1
# අවතක්සේරු   1
# අවදානම්    2
# අවදානමෙන්   1
#   අවදි     1
#  අවදිව     1
# අවධාරණය    1
#  අවධියට    1
# අවබෝධතා    1
# අවභාවිත    1
#   අවම      2
#  අවමගුල    2
# අවමගුල්    1
#  අවමයි     1
#  අවශ්ය     1
# අවශ්යතාවක්   1
# අවශ්යතාවය   1
#  අවසන්     11
# අවස්ථාව    3
# අවස්ථාවට   1
# අවස්ථාවන්   1
# අවස්ථාවෙන්   1
# අවස්ථාවේ   1
# අවස්ථාවේදී   1
#  අවසාන     1
#  අවසානය    1
# අවසානයේ    2
# අවසානයේදී   1
# අවාසනාවට   1
# අවිනිශ්චිත   1
#  අවිෂ්ක    1
# අවුරුදු    7
#   අවුල     3
#  අසනීප     1
#  අසරණයි    1
#   අසරන     2
#  අසලංක     1
# අසලින්ම    5
# අසහනකාරී   1
#  අස්වීම    1
# අසාදිතයින්   1
# අසාර්ථක    1
# අසික්කිත   1
#  අසුපු     1
#   අසුබ     1
#   අසෝක     2
#   අහක්     1
#  අහනවා     1
#  අහන්න     1
#  අහමති     1
#   අහයි     4
#  අහසින්    1
#  අහිමි     7
#  අහිමිව    1
#   අහු      1
# අහුවෙයන්කො   1
#  අහෝසි     1
# අළුත්වැඩියාවට   1
#  අළුයම     1
#   අැති     1
#  අැරපු     1
#   අැරල     1
#    ආ       2
# ආකර්ෂණය    3
#  ආකෘතිය    1
#  ආචාර්ය    2
#  ආඩම්බර    1
# ආඩම්බරෙන්   1
# ආණ්ඩුක්රම   1
# ආණ්ඩුකාර   1
#  ආණ්ඩුව    5
# ආණ්ඩුවට    5
# ආණ්ඩුවෙන්   1
# ආණ්ඩුවේ    3
#   ආදරය     2
#  ආදරයයි    1
# ආදරයෙන්    1
# ආදර්ශයක්   1
#   ආදරේ     3
#   ආදී      1
#   ආධාර     1
#   ආන්      1
#  ආන්ටි     1
#  ආන්ඩුව    1
# ආන්ඩුවෙ    1
# ආන්දෝලනාත්මක   1
#   ආපදා     1
#  ආබාධය     1
# ආබාධයක්    3
# ආයතනයක්    1
#  ආයතනයට    1
# ආයතනවලින්   1
# ආයුබෝවන්   1
#   ආයේ      1
#  ආයෝජන     1
#    ආර      1
#  ආරංචි     1
# ආරංචියක්   1
#  ආරක්ෂක    3
#  ආරක්ෂා    2
#  ආරම්භ     2
# ආරම්භයද    1
#   ආර්      2
#  ආර්ථික    1
# ආර්ථිකය    3
#  ආර්යා     2
# ආරාධනයක්   1
#  ආරුත්     1
#   ආවදා     1
#  ආවරණය     2
# ආශ්රීතයන්   1
# ආශිර්වාදය   1
#  ආසනයක     1
#  ආසන්න     2
# ආසන්නයි    1
#  ආසන්නව    1
#  ආසාදනය    2
#  ආසාදිත    20
# ආසාදිතයන්   4
# ආසාදිතයින්   30
# ආසාදිතයෝ   2
# ආසාදිතව    1
# ආසාධිතයින්   3
#  ආසියා     1
# ආසියාතික   1
# ආසියානු    9
# ආසියාවෙ    1
# ආසියාවෙන්   2
# ආසියාවේ    1
#   ආහාර     1
#   ඇඟට      3
# ඇඟපුරාම    1
# ඇඟවීමක්    1
# ඇඟිල්ලේ    1
# ඇඩොමිලියන   1
#    ඇත      21
#   ඇත්ත     5
#  ඇත්තටම    1
#  ඇත්තද     2
#  ඇත්තෙ     1
#  ඇත්තෙම    1
#  ඇත්තේ     8
# ඇත්ලටික්ස්   1
#  ඇතැම්     2
#  ඇතැයි     2
#   ඇති      28
#  ඇතිකළ     1
#   ඇතිව     1
#  ඇතිවන     1
#  ඇතිවු     2
#  ඇතුලේ     1
#   ඇතුව     2
#  ඇතුළත්    2
#  ඇතුළු     7
#   ඇදුම     1
# ඇදුමක්වත්   1
#  ඇදුම්     1
# ඇදුම්ගැන   2
# ඇනතනීගේ    1
# ඇන්තනීට    1
#    ඇඳ      1
#  ඇඳගෙන     1
#  ඇඳගෙනද    3
#   ඇඳුම     1
#  ඇඳුමක්    3
#  ඇඳුම්     1
#    ඇප      1
#   ඇමති    148
# ඇමතිආණ්ඩුව   1
# ඇමතිකම්    1
#  ඇමතිට     1
# ඇමතිටත්    1
# ඇමතිතුමා   2
#  ඇමතිලා    2
# ඇමතිවරු    3
#  ඇමතීමට    1
# ඇමතුමක්    1
# ඇමරිකන්    2
# ඇමරිකානු   1
# ඇමරිකාව    1
# ඇමරිකාවට   1
# ඇමරිකාවේ   2
#  ඇමැති     3
# ඇමැතිවරයාගේ   1
# ඇමෙරිකානු   1
# ඇමෙරිකාවයි   1
#   ඇයගේ     2
#   ඇයට      1
#   ඇයම      1
#   ඇයි      12
#   ඇරඹේ     2
#  ඇරැඹේ     1
#  ඇරියස්    1
#  ඇල්ලු     1
#  ඇවිත්     4
# ඇවිලීමකින්   1
# ඇස්ට්රාසෙනෙකා   2
# ඇස්ට්රාසොනිකා   1
#  ඇස්වලට    1
#   ඇහුන     1
#  ඇහුනත්    1
#  ඇහුවද     1
# ඇෆ්ගනිස්ථානය   1
# ඇෆ්ඝනිස්ථානයේ   1
#   ඈත්      1
#  ඈත්වී     1
# ඉක්මණින්   1
#  ඉක්මන්    3
# ඉක්මවයි    1
#  ඉක්මවා    3
# ඉගැන්වීම   1
#    ඉඩ      1
#   ඉඩක්     1
#   ඉඩමක     2
#  ඉඩමකඒක    1
#  ඉඩමකින    1
# ඉඩමකින්    1
#   ඉඩම්     19
#   ඉතා      4
# ඉතාලියේ    1
#   ඉතිං     1
#  ඉතින්     5
#  ඉතිරි     1
#  ඉතිරිව    1
# ඉතිහාසය    1
# ඉතිහාසයේ   3
#  ඉදගෙන     2
#   ඉදන      1
#   ඉදන්     1
#   ඉදි      1
#  ඉදිකරන    1
#  ඉදිරි     4
# ඉදිරිපත්   6
# ඉදිරිපිට   4
# ඉදිරියටත්   1
# ඉදිරියෙන්   1
# ඉදිරියේ    3
# ඉදිරියේදි   2
# ඉදිරියේදී   2
#   ඉන්      1
# ඉන්දියාව   4
#  ඉන්දීය    4
#  ඉන්දු     1
# ඉන්දුනීසියාවෙන්   1
#  ඉන්ධන     4
#   ඉන්න     10
# ඉන්නකන්    1
# ඉන්නකොට    1
#  ඉන්නව     1
#  ඉන්නවා    3
# ඉන්නවානමුත්   1
#  ඉන්නෙ     2
#  ඉන්නේ     6
#   ඉඳන්     3
#  ඉඳලනෙ     1
#  ඉපදීම     1
# ඉපදීමයි    1
# ඉම්තියාස්   1
#  ඉරිදා     5
#  ඉරිපත්    1
#  ඉරියව්    1
#  ඉලක්ක     1
#  ඉලක්කය    1
#  ඉල්ලන     1
# ඉල්ලනවා    1
# ඉල්ලන්න    1
#  ඉල්ලපු    1
#  ඉල්ලයි    4
#  ඉල්ලලා    1
#  ඉල්ලා     2
# ඉල්ලාගත්   1
# ඉල්ලීමට    3
# ඉල්ලීම්    1
# ඉල්ලුවා    1
#   ඉවතට     1
#   ඉවත්     3
# ඉවත්කොට    1
# ඉවත්වීමට   1
#  ඉවරයි     2
# ඉවරවෙනව    1
# ඉවෙන්ට්    1
#  ඉශාන්     1
# ඉශාලිනිගේ   3
#  ඉෂාන්     1
# ඉෂාලිනි    3
# ඉෂාලිනිගේ   9
# ඉෂාලිනී    2
# ඉෂාලිනීගේ   7
#   ඉසව්     6
#  ඉසව්ව     1
# ඉසව්වක්    1
#  ඉසව්වට    1
#  ඉසව්වෙ    1
# ඉසව්වේදී   1
# ඉස්කෝලේ    1
# ඉස්සරනම්   1
# ඉස්සරහට    1
# ඉස්සරහින්   1
# ඉස්සුවා    1
#  ඉසුරු     2
#   ඉහත      1
#   ඉහල      1
#   ඉහලට     3
#   ඉහලම     1
#   ඉහළ      4
# ඉහළගොස්    1
#   ඉහළට     3
#    ඊ       1
#   ඊටත්     1
#   ඊයෙ      1
#  ඊයෙත්     1
#   ඊයේ      29
#    උං      1
# උගන්නපන්   2
# උගන්වන්න   2
# උගස්තියලා   1
#   උගෙ      1
#  උණුසුම    2
# උණුසුම්    1
# උත්තරයක්   1
#   උදව      1
#   උදව්     1
# උද්ඝෝෂණ    7
# උදාකරගත්   2
#   උදාන     2
#  උදෙසා     1
#   උදේ      1
#   උදේම     2
#    උන      2
#   උනහම     1
#   උන්      3
#   උන්ට     2
#  උන්ටත්    1
#  උන්නා     1
#   උන්ව     1
#   උනා      5
#   උනාද     1
#   උනාම     1
#  උනුත්     1
#   උනේ      2
#  උනොත්     1
#    උප      2
#  උපකරණ     1
# උපතින්ම    2
#  උපදෙස්    1
# උපන්දින    1
# උපයාගත්    1
#  උපරිම     1
# උප්පැන්න   1
#   උපා      1
#   උපාය     1
# උපාලිගේ    1
#  උපුටා     1
#  උපුල්     1
# උපේක්ෂා    2
#   උබල      1
#    උඹ      2
#   උඹලට     1
#   උරගා     1
#   උරුම     2
#   උලෙල     1
#    උස      1
#  උසාවි     1
# උසාවියකින්   2
# උසාවියට    1
# උසාවියත්   1
#   උළලේ     1
#   උළෙල     6
#  උළෙලක්    1
#  උළෙලට     1
#  උළෙලේ     18
# උළෙලේදී    3
#    එ       2
#    එක      30
#   එකක      2
#   එකකට     2
#   එකකම     1
#   එකක්     9
#  එකකුත්    1
#  එකඟතාව    1
#   එකට      4
#  එකටත්     1
#   එකටම     1
#   එකත්     1
#  එකතුව     1
#   එකදු     1
#   එකම      6
#   එක්      4
#   එක්ක     7
#  එක්කර     1
#  එක්කලා    1
# එක්කෝටි    1
#  එක්තරා    1
#  එක්දින    1
# එක්රැස්    1
# එක්වෙයි    1
# එක්වේවිද   1
#  එක්සත්    7
# එක්සයිස්   1
# එක්ස්ප්රස්   1
#   එකා      1
#  එකාත්     1
#  එකෙක්     1
#  එකෙක්ට    1
#   එකේ      8
#  එගෙන්     1
#  එච්චරම    1
#  එතකොට     2
#   එත්      1
# එතුමන්ට    1
#  එතුමා     2
#   එදා      3
#   එදාට     2
#    එන      4
#  එනකන්     1
#   එනම්     1
#   එනවා     1
#   එන්න     3
#  එන්නත     13
#  එන්නත්    9
# එන්නත්කරණය   2
# එන්නත්කරණයට   1
#  එන්නතේ    2
#  එන්නේ     2
#   එපා      6
#  එබිලා     1
#    එම      10
#  එමීර්     6
#    එය      3
#  එයාගේ     1
#   එයාට     1
#  එයාලට     1
#  එයින්     1
#   එරට      2
#  එරෙහි     4
#  එරෙහිව    5
#    එල      2
#   එල්ල     3
#  එල්ලුව    1
#   එලි      1
# එලොපුවම    1
#   එවකට     1
#  එවරට්     1
#   එවල      1
#  එවැනි     1
#  එවුන්     2
#   එහි      9
#  එහිදී     1
#  එහෙනම්    4
#   එහෙම     3
# එළදෙනක්    1
#  එළඹීමට    1
#  එළඹුණා    1
#  එළඹෙන     2
#  එළියට     1
#    ඒ       37
#    ඒඒ      1
#    ඒක      4
#   ඒකකය     6
#  ඒකකයක්    1
#  ඒකකයේ     1
#   ඒකට      3
#   ඒකත්     1
# ඒකාදිපතියන්ගේ   1
# ඒකාධිපතී   1
#  ඒකාලේ     1
#  ඒජේඑම්    1
#   ඒත්      7
#   ඒමට      1
#   ඒයි      1
#    ඒව      2
#   ඒවා      5
#   ඒවී      1
# ඔඩුදුවලා   1
#   ඔන්න     2
#  ඔප්පු     1
#    ඔබ      1
#   ඔබට      1
#   ඔබත්     1
# ඔබතුමාට    1
#   ඔබලා     6
#  ඔබලාට     1
#  ඔබුචි     1
#   ඔබේ      1
#    ඔය      10
#   ඔයා      1
# ඔලිම්පික්   59
# ඔලිම්පික්හි   1
# ඔව්මෙතන    2
#  ඔවුනට     1
#  ඔවුන්     2
# ඔවුන්ගෙ    1
# ඔවුන්ගේ    1
# ඔස්ට්රේලියානු   3
#  ඔසාකා     1
#  ඔසොවා     1
#   ඔහු      11
#  ඔහුගේ     2
#   ඔහුට     1
#   ඔහේ      1
#   ඔහොම     2
#  ඔීනෑම     1
#    ඕං      1
#    ඕක      1
#   ඕකෙ      1
# ඕගොල්ලො    1
#    ඕන      5
#   ඕනා      2
#   ඕනි      2
#   ඕනෙ      2
#   ඕනේ      1
#   ඕයි      1
#   ඕවට      1
#  ඕවරයේ     1
#   ඕවා      3
# ඕස්ට්රේලියානු   2
#   ඖෂධ      3
#    ක       7
# කඟවේණුන්ගේ   1
#    කට      10
#  කටයුතු    10
#  කට්ටක්    1
#  කට්ටිය    2
# කට්ටියට    1
#   කටාන     1
# කටුගස්තොට   1
# කටුනායක    1
# කඩයිමක්    1
#   කඩා      1
# කඩාවැටීමට   1
# කඩිනමින්   3
#   කඩේ      2
#   කණ්      1
# කණ්ඩායම    4
# කණ්ඩායමක   1
# කණ්ඩායමකට   1
# කණ්ඩායමක්   2
# කණ්ඩායමට   2
# කණ්ඩායමේ   3
#  කණිෂ්ඨ    1
#  කණුවට     1
#   කතා      3
# කතාකරනකොට   1
#   කතාද     1
# කතාබහක්    2
#   කතාව     1
#  කතාවක්    2
#  කතාවේ     1
#    කථ      1
#   කථා      1
#  කදවුර     3
#  කනගාටු    1
#   කනව      1
#   කනවද     1
#   කනවා     1
# කන්ට්රෑක්   1
# කන්ඩායම්   1
#  කන්දයි    1
#   කන්න     2
#  කන්නෙ     1
#  කන්නේ     1
#  කඳවුර     7
# කඳවුරඉදිරිපිට   1
#  කඳුළක්    1
# කපටියෝයරාජපක්ෂ   1
#   කප්      1
#  කප්පම්    1
#  කපාහැර    1
#    කම      1
#   කමක්     1
#   කමට      2
#   කමද      2
#   කම්      1
#  කම්කරු    1
# කම්කරුවන්ගේ   1
#  කමිටුව    1
# කමිටුවෙ    1
# කමිටුවෙන්   1
# කමෙනුත්    1
#    කර      43
#  කරගත්     1
# කරගත්තා    1
#  කරගන්න    3
# කරගන්නවත්   4
#  කරගෙන     1
#   කරණ      2
#   කරත්     1
#   කරති     1
#   කරදර     2
#  කරදීමට    1
#   කරන      27
#  කරනලද     1
#   කරනව     1
#  කරනවනෙ    1
#  කරනවා     15
#   කරන්     2
#  කරන්න     26
# කරන්නනෙ    1
# කරන්නැයි   1
#  කරන්නේ    4
#   කරනු     1
# කරපල්ලකෝ   1
#   කරපු     3
#   කරමි     1
#  කරමින්    8
#   කරමු     1
#   කරයි     19
#  කරයිද     1
#   කරයී     1
#   කරලා     10
#   කරවන     1
#  කරවීම     1
#  කර්නල්    1
# කර්මාන්ත   1
# කර්මාන්තයට   1
#   කරා      2
# කරාපිටිය   2
# කරැනාකර    8
# කරුණාරත්න   2
#  කරුණු     3
# කරුවන්ට    1
#   කරේ      1
#    කල      5
#   කලකට     1
#   කල්      3
#  කල්ලි     1
#   කලා      6
#  කලාපීය    1
#   කලාව     2
#  කලින්     5
#   කලේ      5
#    කව      1
# කවදාවත්    1
#   කවර්     1
#  කවරේද     1
#   කව්ද     1
# කව්දැයි    1
#   කවි      1
#   කවුද     4
#  කවුරු     1
# කවුරුත්    2
# කවුරුහරි   1
# කසාදයක්    1
#  කසුන්     2
#    කළ      24
# කළමනාකරණය   5
#   කළඹන     1
#   කළා      4
#   කළාය     1
#   කළු      5
#  කළුතර     2
#   කළේ      2
#   කළේය     5
#    ක්     168
#   ක්ම      1
#   ක්රම     5
# ක්රමන්ත්රණයට   1
#  ක්රමය     3
#  ක්රමයට    1
# ක්රමයේම    1
# ක්රමවේදය   1
# ක්රමවේදයට   1
# ක්රිකටර්ස්   1
# ක්රිකට්    6
# ක්රිකට්ම   1
# ක්රිඩාංගණය   1
# ක්රියාකරුවන්ගෙන්   1
# ක්රියාත්මක   9
# ක්රියාමාර්ග   2
# ක්රියාව    2
# ක්රියාවන්වලට   1
# ක්රිස්ටෝපර්   4
#  ක්රීඩක    2
# ක්රීඩකයන්   1
# ක්රීඩකයන්ට   2
# ක්රීඩකයින්   1
# ක්රීඩකයින්ට   2
# ක්රීඩකයො   2
#  ක්රීඩා   111
# ක්රීඩාංගණයේදී   1
# ක්රීඩාංගනය   2
# ක්රීඩාතරුණ   1
# ක්රීඩාත්   1
# ක්රීඩාව    7
# ක්රීඩාවක්   3
# ක්රීඩාවට   2
# ක්රීඩාවෙන්   1
# ක්රීඩාවේ   3
# ක්රීඩිකයෙක්   1
# ක්රීඩිකා   1
# ක්රීඩිකාව   1
# ක්රීඩිකාවක්   1
# ක්රීඩිකාවො   1
#  ක්වත්     2
#  ක්වාන්    1
#   ක්වූ     1
# ක්ෂේත්ර    3
# ක්ෂේත්රයටම   1
# ක්ෂේත්රයේ   1
#    කා      1
#  කාටත්     3
#  කාටවත්    1
#  කාණ්ඩය    1
#  කාන්තා    6
# කාන්තාවක්   1
# කාන්තාවන්   4
# කාන්තාවන්ට   2
#  කාබන්     1
#  කාබනික    2
# කාමරයේදී   2
# කාරයෙක්    1
#  කාරයො     1
#   කාර්     1
# කාර්තුවේදී   1
#  කාර්ය     1
# කාර්යාලය   2
# කාර්යාලයට   1
# කාර්යාලයේ   1
# කාර්යාලයේදී   1
#   කාල      1
#   කාලය     2
#  කාලයක්    4
#  කාලයන්    1
# කාලයෙන්    1
#   කාලෙ     6
#  කාලෙකට    1
#  කාලෙට     1
#  කාලෙම     1
#   කාලේ     2
# කැඩෙනකල්   2
#  කැදවා     1
#  කැඳවනු    1
#  කැඳවයි    1
# කැපකිරීම්   1
# කැපවිමෙන්   1
#  කැපවීම    2
# කැපවීමෙන්   1
#   කැපී     1
# කැබිනට්    5
#  කැමති     2
# කැමතියි    1
# කැම්පස්    1
# කැලණියේ    1
#  කැළණි     4
# කෑගහන්නෙ   1
#   කෑම      1
#   කෑවා     1
#    කි      9
# කිංස්ලි    1
#   කිට්     1
#   කින්     8
#   කියන     8
#  කියනවා    1
#  කියන්න    2
# කියන්නැතුව   1
# කියන්නෙ    2
# කියන්නෙම   1
# කියන්නේ    6
#  කියයි     7
#   කියල     8
#  කියලත්    1
#  කියලා     20
# කියලාඑයා   1
#  කියලාද    1
# කියවන්න    1
#   කියා     2
# කියාගෙන    1
# කියැවීම    1
# කියුබානු   1
#   කියූ     1
# කිරිබත්    1
#  කිරිම     1
#  කිරීම     12
# කිරීමක්    2
#  කිරීමට    10
#  කිරීමේ    1
#  කිරුළු    1
# කිලීගෙනුත්   1
#   කිලෝ     4
# කිලෝවක්    1
#  කිව්ව     2
# කිව්වතරුණයෙක්   1
#  කිව්වම    1
#  කිව්වා    5
# කිව්වානම්   1
# කිව්වෙත්   1
#  කිව්වේ    1
#  කිෂන්     1
#   කිසි     1
# කිසිදිනක   1
#  කිසිදු    1
#  කිසිම     3
# කිසියම්    1
# කිසිවක්    2
# කිහිපදෙනෙක්   2
# කිහිපයකට   1
# කිහිපයක්   2
#    කී      3
#  කීයක්     1
#  කීයෙන්    1
# කීර්තිය    1
#   කීවා     1
#  කීවේද     1
# කුට්ටියට   1
#   කුඩා     1
#  කුඩාම     1
# කුමණ්ත්රනයක්   1
#   කුමන     2
# කුමන්ත්රණයක්   1
#  කුමාර     2
# කුමාරතුංගගේ   1
# කුර්නාල්   1
# කුරුණෑගල   2
#  කුලියට    3
#  කුසලතා    1
# කෘෂිකර්ම   2
# කෘෂිකර්මාන්තයක්   1
#   කෙටි     1
# කෙන්ඩ්රික්ස්   1
#  කෙනාද     1
#  කෙනෙක්    8
# කෙනෙක්ගෙ   2
# කෙනෙක්නෙ   1
#  කෙනෙකු    1
# කෙනෙකුගේම   1
# කෙරුවාවෙන්   1
#  කෙරෙහි    1
#   කෙරේ     4
# කෙලවෙනකම්   1
# කෙලවෙලා    1
# කෙලින්ම    1
# කෙසෙල්වතත්   1
#  කෙසේද     1
# කෙහෙළිය    2
# කෙහෙළියමෙහෙමයි   1
# කෙළවෙනකම්   1
#    කේ      1
#   කේටි     1
# කොංග්රසයේ   1
#   කොකා     3
#   කොට      3
#  කොටසක්    1
#  කොටසේ     1
# කොට්ඨාශය   2
# කොට්ඨාශයකට   1
# කොට්ඨාස    3
# කොට්ඨාසය   3
# කොට්ඨාසයේ   1
#  කොටුවෙ    1
# කොඩිතුවක්   1
#  කොඩිය     5
#   කොතන     1
# කොතලාවල    3
# කොන්සියුලර්   1
# කොමසාරිස්   2
# කොම්පැනිය   1
# කොම්පැනියට   1
# කොම්රේඩ්ස්ලාගේ   1
#  කොමිසම    4
# කොරන්ටයින්   2
# කොරියාවෙන්   1
# කොරියාවේ   2
#  කොරෝනා    47
# කොරෝනාවෛරසය   4
#  කොලුවා    1
#  කොවිඩ්    77
# කොවිඩ්ඩ්   1
# කොහාටදැයි   2
#  කොහෙද     1
#  කොහෙන්    1
# කොහේවත්    1
# කොහොමත්    1
#  කොහොමද    4
#   කොළඹ     10
# කොළොම්බස්   2
# කොළොම්බස්ගේ   1
# කොළොම්බස්ගේත්   1
#    කෝ      3
#  කෝච්චි    1
#   කෝටි     3
# කෝටිපතියො   1
# කෝපරේෂන්   1
#  කෝවිඩ්    1
#   ඛණ්ඩ     1
#   ඛනිජ     1
#    ගග      1
#    ගඟ      6
#   ගණන      11
#   ගණන්     1
#  ගණනාවක    1
# ගණනාවක්    1
#    ගත      2
#   ගතවු     1
#   ගතවූ     1
#   ගත්      4
#   ගත්ත     3
#  ගත්තා     2
#  ගත්තාද    1
#   ගනන      1
#  ගනනක්     2
#   ගනන්     2
#   ගන්න     4
#  ගන්නවා    1
#  ගන්නා     3
# ගන්නැති    1
#  ගන්නේ     1
# ගන්වනවට    1
# ගනිමින්    4
#  ගනියි     2
#   ගනී      1
#   ගනු      1
#    ගම      1
#   ගමට      1
#   ගමන      3
#   ගමන්     5
#   ගමනේ     1
#  ගම්පහ     3
# ගම්මානයට   1
#   ගමේ      1
#   ගරු      10
#   ගලක්     5
#   ගල්      2
# ගල්ලෙනක    5
#  ගලායන     1
# ගලෙන්බිඳුණු   2
#   ගසා      1
#    ගහ      1
#  ගහගන්න    1
#  ගහද්දී    1
#   ගහන      1
#  ගහනවා     2
#  ගහන්න     4
#   ගහපු     2
#   ගහලා     2
#  ගහෙන්     1
# ග්රන්තී    1
# ග්රාමිය    1
# ග්රාමීය    2
#  ගාණක්     1
#  ගාණත්     2
# ගානකින්    1
#  ගානටත්    1
#  ගානෙන්    1
# ගාල්කරන්නේ   1
#  ගාල්ල     1
#   ගාලේ     1
# ගැටලුවට    1
# ගැටලුවලට   1
#  ගැටළුව    1
#  ගැණුනි    1
#   ගැන      21
#   ගැනම     1
#  ගැනීම     4
# ගැනීමකින්   1
#  ගැනීමට    9
# ගැනීමෙන්   1
#  ගැනීමේ    2
#   ගැනේ     1
# ගැලවෙන්න   1
#  ගැසට්     2
#   ගෑණු     1
#   ගෑවද     1
# ගිගුම්දෙයි   1
#  ගිණුම්    1
#   ගිනි     5
# ගිනිපොළියට   1
#   ගිය      15
#  ගියත්     1
#  ගියපු     1
#   ගියා     1
#  ගියාම     2
#  ගියෙට්    1
#   ගියේ     5
#  ගියේය     2
#  ගියොත්    2
#  ගිලන්     1
# ගිවිසුමක්   1
#  ගිහානී    1
#  ගිහිං     3
#  ගිහින්    5
# ගිහිල්ලා   1
#   ගීතය     1
#  ගුණයට     1
# ගුණරත්න    2
# ගුණවර්ධන   7
#  ගුණාංග    1
# ගුරැවරැ    1
# ගුරැවරැන්ට   1
#   ගුරු     21
# ගුරුවරු    3
# ගුරුවරුන්ගෙන්   1
# ගුරුවරුන්ගේ   1
# ගුරුවරුන්ට   3
#  ගුවන්     11
#    ගෙ      1
#   ගෙදර     6
#  ගෙදරට     1
#   ගෙන      20
# ගෙනදෙමින්   1
#  ගෙනයයි    1
# ගෙනල්ලා    1
#   ගෙන්     2
#  ගෙනාපු    1
#  ගෙනාවම    1
#   ගෙනි     1
#   ගෙල      5
#  ගෙවනව     1
#  ගෙවන්න    1
# ගෙවන්නේ    1
#  ගෙවලා     1
#  ගෙව්වද    1
#   ගෙවා     1
#  ගෙවිඳු    1
#  ගෙවීමට    1
#  ගෙහානි    1
#   ගෙළ      2
#    ගේ      9
#  ගේන්න     1
#   ගේම්     1
#    ගො      1
#  ගොටාබය    1
#   ගොඩ      3
#  ගොඩක්     4
# ගොඩගත්තේය   2
# ගොඩගන්න    2
# ගොඩගැනීම   1
# ගොඩගැසීමයබැංකොක්   1
#  ගොඩගෙන    1
# ගොඩනඟන්න   1
# ගොඩනැගිල්ල   1
# ගොඩනැඟුණු   1
# ගොඩවන්න    1
# ගොදුරුව    1
#   ගොන්     2
#  ගොනුකර    3
#  ගොබ්බ     1
# ගොබ්බයෙක්   1
# ගොබිලෙක්   1
#  ගොල්ෆ්    1
# ගොවියාගේ   3
# ගොවියෙකුට   1
#  ගොවියෝ    1
#  ගොවීන්    1
#   ගොස්     2
#  ගොසින්    1
#  ගෝඨාබය    1
# ගෝඨාභගෙන්   1
#  ගෝඨාභය    30
# ගෝඨාභයයි   1
# ගෝලයෙක්    2
#  ගෞතම්     1
# ගෞරවයක්    1
#   ඝාතන     1
#  ඝාතනය     1
#  චන්දෙ     1
#  චන්දේ     1
#   චමල්     1
#  චමල්ගේ    2
#   චමීර     1
#   චරිත     2
#  චරිත්     1
#   චානක     2
#   චාමර     1
#  චාමික     1
# චාමිකගෙ    1
# චායාරුපෙ   1
# චායාරූප    1
#  චාහල්     1
#  චිනයේ     8
#   චීන      1
#  චීනගෙ     1
#   චීනට     1
#   චීනය     3
#  චීනයට     2
# චීනයටත්    1
#  චීනයේ     2
# චීනාගෙන්   1
#   චීනෙ     1
#  චීනෙට     2
#   චුන්     1
# චූදිතයන්   1
# චූදිතයින්ට   1
#  චෙරන්     1
#  චෝදනා     3
# චෝදනාවට    1
# ඡන්දයේදී   2
#  ඡන්දෙ     1
# ඡායාරූප    2
# ඡායාරූපගත   1
#    ජන      6
#   ජනතා     3
#  ජනතාව     4
# ජනතාවගෙන්   1
#  ජනතාවට    6
#  ජනපති     8
#  ජනපතිට    1
# ජනපතිවරනය   1
# ජනප්රිය    2
# ජනප්රියම   1
# ජනමාධ්ය    1
#   ජනයා     1
#  ජනරාල්    1
# ජනරාල්වරයා   8
#  ජනවාරි    1
# ජනාධිපති   22
# ජනාධිපතිතුමනි   1
# ජනාධිපතිතුමා   1
# ජනාධිපතිධූරයේ   1
# ජනාධිපතිවරණයේ   1
# ජනාධිපතිවරනයෙන්   1
# ජනාධිපතිවරයා   2
# ජනාධිපතිවරයාගේ   1
#    ජප      1
#   ජපන්     1
#   ජපාන     2
#  ජපානය     4
# ජපානයෙන්   1
#  ජපානයේ    5
#  ජපානේ     1
#  ජමාත්     1
#    ජය      4
#  ජයගත්     1
#  ජයගමු     4
#  ජයග්ර     1
# ජයග්රහණ    2
# ජයග්රහණය   3
# ජයග්රහණයක්   1
# ජයග්රහන    1
#  ජයගෙන     1
# ජයමාන්න    1
#  ජයරත්න    1
# ජයවික්රම   1
#  ජයසිංහ    1
# ජයසිංහට    4
#  ජයසුමන    1
#  ජයසේකර    1
# ජර්සියක්   1
#    ජල      6
#   ජලජ      6
#   ජලය      2
#    ජව      1
#   ජවය      1
# ජ්යෙෂ්ඨ    3
# ජාත්යන්තර   4
# ජාත්යාලය   1
#  ජාතික     19
# ජාතිකත්වය   2
#  ජාතිය     1
# ජාතීන්ගේ   1
# ජාවාරමක    1
# ජාවාරමක්   1
# ජාවාරමෙන්   1
# ජැක්සන්    1
# ජිම්නාස්ටික්   4
# ජිව්තයයි   1
#  ජිවිතේ    1
# ජීඑල්ගෙන්   1
#   ජීව      1
#  ජීවත්     1
#  ජීවන්ත    2
#   ජීවි     1
#  ජීවිත     3
# ජීවිතක්ෂයට   1
# ජීවිතේම    1
#   ජුඩ්     1
#   ජුනි     1
#   ජුලි     2
#   ජූඩ්     2
#   ජූලි     11
# ජෙනරාල්ට   1
# ජෙනරාල්වරයෙකුගේ   1
# ජෙප්පන්ගේ   1
#  ජෙප්පෝ    1
#   ජෙෙන     1
#    ජේ      1
# ජොන්ස්ටන්   1
# ඥාතියෙක්   1
# ඥාතීන්ගෙන්   1
#    ට       28
#   ටත්      1
#    ටම      2
#   ටයි      2
# ට්රිපොලි   1
# ට්විටර්    1
# ටැබ්දීමෙන්   1
#   ටික      1
#  ටිකකට     1
#  ටිකක්     1
#   ටිකට     1
#   ටික්     1
# ටියුෂන්    2
#   ටීම්     2
#  ටෙනිස්    3
#   ටොක්     1
#   ටොන්     1
#  ටෝකියෝ    8
# ටෝකියෝහිදී   1
#  ඩන්කන්    2
#   ඩයගම     1
#   ඩයල්     1
#   ඩයස්     2
#   ඩලස්     1
#  ඩ්රෝන     2
# ඩික්සන්    1
#  ඩියුබා    1
#    ඩී      1
#  ඩෙංගු     1
# ඩේසිආච්චි   1
#  ඩොලර්     2
#    ණය      5
#   ණයක්     1
#    ත       1
#  තණ්හාව    1
#   තත්      1
#  තත්වය     1
#  තත්වයක    1
# තත්වයක්    1
#  තදින්     1
#  තනියම     2
#  තනිවීම    1
#  තප්පර     1
#  තබමින්    1
#   තබා      1
#  තබාගෙන    1
#    තම      3
#   තමන්     5
#  තමන්ගේ    1
#   තමයි     17
#   තමා      1
#   තමාට     1
#    තර      1
#   තරග      10
#   තරගය     4
# තරගයකින්   1
#  තරගයට     1
#  තරගයත්    1
# තරගයෙන්    1
# තරගයේදී    1
# තරගාවලිය   4
# තරගාවලියට   2
# තරගාවලියෙන්   1
# තරගාවලියේ   2
#   තරඟ      8
# තරඟබිමේදි   1
#   තරඟය     3
# තරඟයෙන්    1
#  තරඟයේ     1
# තරඟාවලිය   1
#   තරම්     6
#  තර්ජන     11
#  තර්ජනය    1
# තර්ජනයක්   1
#   තරුණ     6
# තරුණියක්   1
#    තව      14
#   තවත්     55
# තවදුරටත්   1
#   තවම      2
#  තවමත්     2
# තව්හිද්    1
#  තහනමකට    1
#  තහනම්     5
#  තහවුරු    12
# තහවුරුවීමේ   1
#    ත්      5
# ත්රිපුද්ගල   2
# ත්රිවිධ    1
# තාක්ෂණයෙන්   1
#  තාත්තා    2
# තාන්ත්රිකයන්   3
# තාන්ත්රිකයින්   1
# තාන්ත්රිකයෝ   1
# තානාපති    1
# තානාපතිවරයා   1
# තානාපතිවරු   2
# තානාපතිවරුන්   1
#   තාම      2
# තායිලන්තය   1
# තායිලන්තයේ   1
#  තාරකාව    1
# තාවකාලිකව   1
#   තැන      2
#   තැනක     1
#   තැනට     2
#   තැනම     1
#   තැන්     2
#  තැබීමට    1
#   තැබූ     1
# තැරව්කරු   1
# තැරව්කාර   1
#    ති      1
#  තිත්ත     1
# තිදෙනෙක්   1
#  තිබ්බෙ    3
#  තිබිණ     2
#  තිබිණි    1
# තිබියදි    1
# තිබියදී    1
#   තිබී     1
#   තිබු     3
# තිබුණත්    2
#  තිබුණි    1
#  තිබුණෙ    1
# තිබුණේද    1
#  තිබුන     2
#  තිබුනා    1
#  තිබුනෙ    1
#   තිබූ     8
#  තිබෙන     8
# තිබෙනවා    7
# තිබෙන්නෙ   1
#  තිබෙයි    1
#   තිබේ     31
#   තියන     1
#  තියනවද    1
#  තියනවා    1
#   තියා     1
# තියාගෙන    4
# තියාපල්ලාකො   1
#  තියුණු    1
#   තියෙ     1
#  තියෙන     2
# තියෙනකන්   1
#  තියෙනව    1
# තියෙනවා    6
# තියෙනවානේ   1
# තියෙන්නෙ   4
# තියෙන්නෙත්   1
# තියෙන්නේ   7
# තියෙන්නෝන   1
#  තියේද     1
#  තිරණය     1
#   තිරය     1
#  තිරසර     1
# තිස්එක්දහසක්   1
#  තිස්සේ    2
#  තීන්දු    2
# තීන්දුකර   1
# තීන්දුව    4
#  තීබ්බ     1
#  තීරණය     9
# තීරණයකට    2
# තීරණාත්මක   1
#  තීර්ථක    1
# තුංවැනි    1
#   තුන      1
#  තුනක්     1
# තුනකින්    1
#   තුන්     2
#  තුන්කල    1
# තුන්ලක්ෂය   1
#  තුන්වන    2
#   තුමා     4
#  තුමාට     1
#  තුරන්     8
#   තුල      2
#  තුලදී     1
#  තුවාල     1
#  තුෂාර     1
#   තුළ      13
#  තුළින්    1
#   තෙක්     2
# තෙන්නකෝන්   1
#  තෙනුක     1
#   තෙල්     1
# තෙල්දෙණිය   1
#  තෙවැනි    1
# තෙහෙළිය    1
#   තේමා     1
#   තේරී     1
# තේරුමකුත්   1
# තේරෙන්නේ   1
#  තේරෙයි    1
#  තොගයක්    2
# තොටුපලට    1
# තොණ්ඩමන්ගේ   1
#  තොපිල     2
#  තොපිලට    1
# තොරතුරු    3
#    තෝ      1
# තෝරාගත්    1
#    ද       18
#   දක්ව     1
#  දක්වන     1
# දක්වමින්   2
#  දක්වයි    1
#  දක්වා     10
#   දක්ෂ     1
#  දක්ෂතා    1
# දක්ෂතාව    1
#  දක්ෂයො    1
#  දකින්න    1
# දකින්නට    3
# දකින්නේ    1
#   දකුණ     1
#  දකුණු     2
#    දඩ      2
#  දඩුවම්    1
#  දඬුවම     1
#  දඬුවම්    2
#  දන්නවද    1
#  දන්නවා    1
#  දන්නෙ     1
#  දන්නේ     1
#  දන්වා     1
#  දම්මික    1
#   දමා      2
#  දයාන්     1
# දයාසිරි    1
#  දරවටත්    1
#  දරවන්     1
#  දර්ශණ     1
# දර්ශණිය    1
#  දර්ශන     2
#  දරැවන්    2
# දරැවන්ට    1
#  දරුණුම    1
#  දරුවන්    2
# දරුවන්ගේ   1
# දරුවන්ට    5
#  දරුවා     2
#  දරුවෝ     2
#   දවස      3
#   දවසක     2
#  දවසක්     1
#  දවසක්ම    1
#   දවසට     2
# දවසලංකාවේ   1
#   දවස්     1
#  දවසින්    1
#   දශක      3
#  දසුන්     1
#   දහම      1
#  දහයක්     1
# ද්විත්ව    1
# ද්විපාර්ශවික   1
#    දා      3
#  දාද්දී    1
#  දානවනෙ    1
#  දානවා     7
#  දාන්න     3
#   දාපු     1
#   දායක     2
#   දාහට     1
#  දැක්කේ    1
#  දැක්මව    1
# දැක්වීමේදී   1
#  දැක්වේ    1
#   දැඩි     1
#  දැඩිව     1
#  දැණුනා    1
#   දැන      5
#   දැනට     2
#   දැන්     13
# දැන්නම්    1
#  දැනුන     1
#  දැනුම්    1
# දැනුම්දී   1
# දැනුවත්ව   1
# දැනෙන්නේ   1
#  දැම්මා    1
#  දැම්මෙ    1
#  දැමිය     1
#  දැමීම     2
#  දැමීමට    2
#   දැමේ     2
#  දැරිය     2
#  දැරියක    2
# දැරියකගේ   1
# දැරියකවූ   1
# දැරියක්    3
# දැරියගේ    11
# දැරියන්ගේ   6
#   දැරු     1
#   දැරූ     1
# දැල්වීමටද   1
# දැවැන්තම   1
#   දෑස්     2
#   දික්     1
#  දිගටම     1
#  දිදුළන    1
#   දින      18
#  දිනකදි    1
#  දිනක්     1
#   දිනය     5
#  දිනයේ     11
# දිනයේදීද   1
#  දිනලා     1
# දින්නන්නම   1
#   දිනා     3
# දිනාගත්    1
# දිනාගෙන    3
#  දිනුජ්    1
#  දිනුම්    1
#  දිනෙන්    1
#  දිනේෂ්    1
#   දිය      4
# දියණියගේ   3
# දියුණුවන   1
# දියුනුගේ   1
#   දිරි     1
# දිරියෙන්   1
#  දිලුම්    1
# දිවයිනේ    2
#   දිවි     1
#  දිවිය     1
#  දිවීම     1
# දිස්ත්රික්   2
# දිස්ත්රික්කයේ   1
#   දිසා     1
# දිසානායක   4
#   දිහා     1
#    දී      36
#  දීගන්න    1
# දීපව්යාප්ත   1
#   දීපු     1
#  දීමනා     1
# දීමනාවක්   1
# දීමනාවට    1
#  දීමෙන්    2
#  දීලත්     2
#   දීලා     2
# දුටුගැමුණු   1
#   දුන්     3
#  දුන්න     2
# දුන්නත්    2
# දුන්නනෙ    1
#  දුන්නම    1
# දුන්නානම්   1
# දුන්නාම    1
#  දුන්නෑ    1
#  දුන්නෙ    1
# දුන්නේය    1
# දුන්නොත්   1
# දුප්පත්    1
# දුප්පත්කම   1
# දුම්බීම    1
# දුමින්ද    2
#   දුර      1
#   දුරට     1
#   දුරය     1
#  දුර්වල    1
# දුර්වලතාවය   1
# දුරාචාර    1
#   දුව      1
#  දුශණයට    1
# දුශ්මන්ත   1
# දුෂණයක්    1
# දුෂිතයො    1
#  දූවලා     1
# දූෂකයෙකුට   1
#   දූෂණ     2
#  දූෂණය     2
#  දූෂණයක    1
#    දෙ      1
#   දෙක      3
#  දෙකකට     1
#  දෙකක්     9
# දෙකකින්    1
#   දෙකට     1
#  දෙකත්     1
#   දෙකම     1
#  දෙකෙන්    1
# දෙදෙනකු    1
# දෙදෙනෙක්   2
# දෙදෙනෙකුට   1
#   දෙන      7
#  දෙනකු     1
# දෙනකුගෙන්   1
#  දෙනවා     3
#  දෙන්න     5
# දෙන්නකෝ    1
# දෙන්නෙක්   2
#   දෙනා     1
#  දෙනාගේ    3
#  දෙනාට     3
# දෙනාටත්    1
#  දෙනාව     1
#  දෙනෙක්    3
#  දෙනෙකු    4
# දෙපාර්තමේන්තු   1
# දෙපාර්තමේන්තුව   4
# දෙපාර්තමේන්තුවට   5
# දෙපාර්තමේන්තුවෙන්   1
#   දෙබෑ     1
# දෙබෑකරන්   1
# දෙමව්පියන්ගෙන්   1
# දෙමාපියන්   1
# දෙමාපියෝත්   1
#   දෙය      1
#  දෙයක්     2
#   දෙයි     1
#  දෙරටේ     1
#  දෙලක්ෂ    1
#   දෙවන     15
#  දෙවනි     3
#  දෙවැනි    3
#  දෙවියෝ    1
#  දෙහිවල    1
#    දේ      1
#   දේපළ     1
#  දේවල්     1
# දේශප්රිය   1
# දේශප්රේමය   1
# දේශප්රේමියෝ   1
# දේශප්රේමීත්වය   1
# දේශප්රේමීන්   1
# දේශපාලකයෝ   1
# දේශපාලන    5
# දේශපාලනඥයන්   1
# දේශපාලනඥයා   1
# දේශපාලනය   1
# දේශපාලනයෙන්   2
# දේශපාලනයේ   1
#  දේශිය     1
#  දේශීය     2
#   දේහය     10
#  දෛනික     8
#  දොස්තර    5
# දොස්තරලා   1
# දෝශාභියෝගයක්   1
#   ධජය      1
#  ධනංජය     5
#  ධනවත්ම    2
#  ධනුෂ්ක    1
#  ධම්මික    1
#  ධර්මය     1
#  ධවාන්     1
#  ධාරණය     3
#   ධාවන     4
#   ධුර      1
#   ධුරය     1
#   ධූර      1
#    න       2
#    නං      2
#   නගර      3
#   නගරය     2
#  නගරයක     1
#  නගරයක්    1
#  නගරයේ     2
# නගරවාසීන්   1
# නගරසභාවේ   1
# නගින්නේ    1
#  නඩත්තු    1
#   නඩු      8
#  නඩුවක්    1
#    නම      2
#  නමගිය     1
#   නමට      1
#   නම්      15
#  නමින්     2
#  නමුත්     5
#  නයවෙලා    4
#  නයෝමි     1
#    නව      20
# නවත්වන්න   1
#   නවතා     1
# නවමෞත්ර    1
# නවසීලන්ත   2
#   නවීන     1
#  නසාගත්    1
#    න්      3
#  නාගමුව    1
#   නාගය     1
#  නාගරික    2
# නාගානන්ද   1
# නානායක්කාර   2
#  නාමල්     12
#  නාමික     1
#   නායක     6
# නායකත්ව    3
# නායකත්වය   1
# නායකත්වයෙන්   1
# නායකයාට    2
# නායකයෙක්   1
#  නායිකා    1
#   නාරී     1
#   නාල      1
#  නාවික     11
#  නාවිකා    1
#  නාවුක     1
#  නාස්ති    2
# නාස්තිය    1
#    නැ      2
#  නැගලා     1
# නැගිටලා    1
#   නැත      5
#  නැතත්     1
# නැත්තන්    1
#  නැත්තෙ    1
#  නැත්තේ    2
#   නැති     14
#  නැතිව     1
#  නැතුව     2
#  නැද්ද     1
#  නැමති     1
#   නැම්     1
#  නැමාස     1
#  නැරඹීම    1
#  නැවටද     1
#   නැවත     4
#  නැවතත්    2
#   නැහැ     16
#    නෑ      23
#   නෑතව     1
#   නෑනෙ     2
#   නෑනේ     1
#   නෑලු     1
#   නිකං     1
#  නිකමට     1
#  නිකුත්    8
# නිතියක්    1
#  නිතියට    3
# නිතියෙන්   1
#  නිතීය     1
#  නිදහස     1
#  නිදහස්    17
# නින්දගමක්   1
# නින්දෙන්   1
#  නිපුන     2
#  නිමල්     2
#   නිමා     1
#  නිමාලි    1
# නිමාලිට    1
#  නිමාව     1
#  නිමාවන    1
# නිමිත්තෙන්   2
#   නියම     2
#  නියමිත    8
# නියමිතයි   2
# නියමිතව    5
# නියාමනයට   1
#  නියෝග     3
# නියෝගයක්   4
# නියෝජනය    2
# නියෝජ්ය    8
# නියෝජිතයන්   1
# නියෝජිතයින්   4
#   නිරත     2
#  නිරතව     1
# නිර්දේශවූ   1
# නිර්දේශිත   1
# නිර්මාණය   2
# නිරීක්ෂණයට   2
# නිරෝධනයට   1
# නිරෝධානයට   2
# නිරෝධායනය   1
# නිරෝධායනයට   13
#   නිල      5
#  නිලතල     1
# නිලදරින්ටයි   2
# නිලධාරින්   3
# නිලධාරියෙක්   2
# නිලධාරියෙක්ද   1
# නිලධාරීන්   3
# නිලධාරීන්ට   2
#  නිලන්ත    1
#  නිලූක     1
# නිලූකගෙ    1
#   නිවස     3
#  නිවසක     1
#  නිවසක්    2
#  නිවස්     1
#  නිවසේ     20
# නිවසේදි    2
# නිවසේදී    2
#  නිවහල්    1
# නිව්මෝනියාව   2
#  නිවාස     1
#  නිවුන්    1
#  නිවෙස     2
# නිවෙස්වල   1
# නිවෙස්වලදී   1
#  නිවෙසේ    1
#  නිවේදන    1
# නිවේදනයක්   1
# නිශ්චිතව   1
# නිෂ්පාදනය   2
# නිෂ්පාදනයක්   4
# නිෂ්පාදිත   9
#  නිෂියා    1
#   නිස      1
# නිසවෙනි    1
#   නිසා     22
#  නිසානෙ    1
#  නිසාලු    1
#  නිහඬයි    2
#   නිළ      2
#   නිළි     2
# නීත්යානුකූල   1
#  නීතිගත    1
#  නීතිඥ     1
# නීතිපතියත්   1
# නීතිපතිවරයා   1
# නීතියක්    2
# නීතියෙන්   1
#   නීසා     1
# නුගේගොඩ    4
#  නුදුරු    1
#  නුවන්     1
#   නුවර     2
# නුවරඑළිය   1
#  නූගත්     1
#   නූතන     1
#  නූලෙන්    5
#    නෙ      1
# නෙදර්ලන්තය   1
#  නෙමෙයි    1
#   නෙමේ     1
#  නෙවිනේ    1
#  නෙවෙයි    1
#   නෙවේ     1
#   නෙහ්     1
#    නේ      3
#   නේද      7
# නේන්නම්    1
#  නේපාල     3
#   නේව්     1
#   නේහ්     1
#   නොක      1
#   නොකර     1
#  නොකරන     1
# නොකරොත්    1
#   නොකල     1
#   නොකි     1
#  නොකිර     1
# නොකිරීම    2
#  නොගත්     2
#  නොතියා    2
#  නොතෙමි    1
# නොතේරේද    1
#  නොදැන     1
#  නොදැවී    1
#  නොදීමට    1
#  නොන්ඩි    3
#   නොබා     1
# නොබැලුවත්   1
#  නොබිඳී    2
#  නොමැත     1
#  නොමිලේ    3
#  නොලත්     1
#   නොවන     8
#  නොවන්න    1
#   නොවූ     1
#  නොවූවා    1
#   නොවේ     3
#  නොවේද     2
#  නොහැකි    1
#  නෞකාව     1
#    ප       2
#   පක්ෂ     4
#  පක්ෂණ     1
#  පක්ෂය     2
#  පක්ෂයේ    3
#  පක්ෂෙට    1
#   පටන්     2
# පටන්ගත්    1
# පටන්ගෙන    1
#  පටවලා     1
#   පට්ට     2
# පට්ටපල්    1
#   පඩිය     1
# පණිවිඩයක්   4
#   පතයි     1
#   පත්      11
#  පත්කල     1
# පත්කිරීම   1
# පත්රයක්    1
# පත්රිකාවක්   2
#   පත්ව     1
#  පත්විය    1
#  පත්වු     1
#    පථ      6
#  පදක්කම    3
# පදක්කම්    14
# පදවිවලින්   1
# පද්ධතිය    1
#  පද්මා     1
#  පදිංචි    2
#   පනත      3
#  පනතක්     1
#  පනතෙන්    1
#   පනතේ     2
# පනස්දාහකට   1
#  පනහක්     1
#  පන්දු     5
#  පන්දුව    4
# පන්දුවක්   1
#   පන්න     2
#  පන්සලට    1
#   පමණ      2
#  පමණක්     2
# පමුණුවා    1
# පඹයෙක්ට    2
#   පරණ      3
#   පරදන     1
# පරදමින්    1
#  පරපුර     1
# පරපුරක්    1
#  පරයාට     1
#  පර්ල්     1
#  පරාජය     1
# පරාජයන්    1
#  පරාජිත    2
#   පරාද     1
#  පරාදයි    1
# පරික්ෂකවරයකු   2
# පරික්ෂණය   2
# පරික්ෂණයක්   1
# පරික්ෂණයේදි   2
# පරික්ෂාවට   1
#  පරිදි     4
#  පරිදිය    1
# පරිශ්රයේ   1
#  පරිසරය    1
# පරිසරයට    1
#   පරීක     1
# පරීක්ක්ෂණ   1
# පරීක්ෂණ    22
# පරීක්ෂණය   15
# පරීක්ෂණයකට   1
# පරීක්ෂණයක්   2
# පරීක්ෂණයට   3
# පරීක්ෂණයෙන්   1
# පරීක්ෂණයේ   1
#   පලමු     4
#   පලය      1
# පල්ලෙගම    1
# පලුගොල්ලෑගම   2
#  පවත්වන    2
# පවත්වයි    1
#  පවත්වා    1
# පවත්වාගෙන   1
#  පවතින     1
# පවතිනවා    1
#   පවතී     1
# පවරමින්    1
#   පවරා     1
#  පවසනවා    2
# පවසමින්    1
#  පවසයි     11
#   පවසා     2
#  පවසිය     1
#   පවා      2
#   පවුල     3
#  පවුල්     1
# පවුල්වල    1
#  පවුලෙ     2
#  පවුලේ     2
# පශ්චාත්    12
#  පස්වරු    1
#  පස්සෙ     1
#   පසු      6
#  පසුකර     1
#  පසුගිය    3
#   පසුව     4
#  පසුවන     3
#   පහක්     1
#   පහත      1
#   පහත්     1
#  පහතින්    1
#   පහර      1
# පහසුකම්    4
# පහසුකම්ද   1
#    පළ      1
# පළකිරිමට   1
# පළපුරුදු   1
#   පළමු     7
#  පළවෙනි    1
#   පළාත     2
#  පළාත්     2
#  පළිගනී    1
#   ප්ර      1
#  ප්රකාශ    8
# ප්රකාශක    5
# ප්රකාශය    1
# ප්රකාශයකට   1
# ප්රකාශයක්   3
# ප්රකාශයට   1
# ප්රගතිය    1
# ප්රචාරයක්   1
#  ප්රජා     2
# ප්රතිකාර   3
# ප්රතිදේහජනක   4
# ප්රතිපත්ති   2
# ප්රතිපල    2
# ප්රතිපාදනවලට   1
# ප්රතිඵල    1
# ප්රතිඵලය   1
#  ප්රථම     4
# ප්රථිකාර   4
# ප්රදර්ශනය   1
# ප්රදානය    1
#  ප්රදේශ    2
# ප්රදේශයේ   6
# ප්රදේශයේදී   3
# ප්රදේශවල   1
# ප්රදේශවලට   1
#  ප්රධාන    4
# ප්රධානත්වයෙන්   8
# ප්රධානී    1
# ප්රනාන්දු   9
# ප්රනාන්දුපුල්ලේ   1
# ප්රබාකරන්ගෙ   1
# ප්රමාණය    2
# ප්රමාණයක්   1
# ප්රමාණවත්   3
#  ප්රමිත    1
#  ප්රමුඛ    1
# ප්රයෝජන    1
# ප්රවණතාව   1
# ප්රවර්ධනය   2
# ප්රවර්ධනයට   3
# ප්රවාහන    3
#  ප්රවීණ    2
# ප්රවීන්    1
# ප්රවේශයට   1
#  ප්රශ්ණ    1
# ප්රශ්නය    2
# ප්රශ්නයක්   2
# ප්රසන්න    3
#  ප්රහාර    2
# ප්රහාරය    2
# ප්රාදේශීය   1
# ප්රැක්ටිස්   2
# ප්රැක්ටිස්වලට   1
# ප්රිමියර්   1
# ප්රියන්ත   1
# ප්රේමදාස   2
# ප්රේමදාසලා   1
#  ප්ලේන්    1
# පාක්ෂිකයන්   3
# පාකිස්තානය   1
# පාණ්ඩ්යො   2
#  පාණ්ඩේ    1
# පාදඩයන්    1
#   පානය     1
#  පානවා     1
#  පාන්දර    1
#  පානීය     2
# පාපන්දු    1
#   පාම      2
# පාමන්ත්රී   1
#   පාරට     3
# පාර්ලිමේන්තු   29
# පාර්ලිමේන්තුවට   3
# පාර්ලිමේන්තුවාර   1
# පාර්ලිමේන්තුවේ   2
#   පාරෙ     2
#  පාලකයා    5
#   පාලන     3
#  පාලනය     1
#  පාලනයට    1
# පාවිච්චි   1
#  පාසලක     1
#  පාසලක්    1
#  පාසල්     2
#   පාස්     2
#  පාස්කු    3
# පාස්සකු    1
#  පැක්කර    1
#  පැණිය     1
# පැත්තකින්   1
#  පැතිකඩ    2
#  පැතුම්    2
#   පැන      1
#  පැනලා     1
#  පැන්නා    1
#   පැනි     1
#  පැනීමේ    1
#  පැමිණ     2
#  පැමිණි    3
# පැමිණිමත්   1
# පැමිණියේය   1
# පැමිණිල්ල   4
# පැමිණීමට   3
# පැමිණෙන    1
# පැමිණෙයි   1
# පැමිනේවි   1
#   පැය      9
#  පැයක්     1
# පැරද්දෙදි   1
#  පැරදී     1
#  පැරදුම    1
# පැලඳගෙන    1
#  පැලඳලා    1
#  පැලෙන     1
# පැලෝපීය    1
#  පැවති     11
#  පැවරීම    1
#  පැවසීය    1
# පැවැත්විමට   1
# පැවැත්වීම   1
# පැවැත්වීමට   8
# පැවැත්වුණ   1
# පැවැත්වූ   5
# පැවැත්වූයේ   1
# පැවැත්වෙන   5
# පැවැත්වෙනු   1
# පැවැත්වෙමින්   1
# පැවැත්වේ   1
#  පැවැති    4
#  පැවිති    1
# පැහැදිලි   2
# පැහැදිලිවම   1
#  පෑදෙයි    2
#   පිං      1
#  පිටත්ව    1
#  පිටපත්    1
#   පිටව     1
# පිටිපස්සෙන්   1
#  පිටිය     3
# පිටියක්    1
#  පිටියේ    1
#  පිටුපස    2
# පිටුවක්    2
#  පිදුම්    1
#   පින      2
#   පිනට     1
#  පියත්     1
#  පියවර     1
#   පියා     2
# පිරිතෙන්   1
#  පිරිමි    6
# පිරිමින්ට   1
#  පිරිස     3
# පිරිසක්    2
#  පිරිසට    1
# පිරිසිදු   2
# පිරිසෙන්   1
#  පිරුණු    1
#   පිල      1
# පිලිගන්න   2
#  පිලිබඳ    2
# පිලිලයක්   1
# පිලිවලක්   1
# පිලිස්සී   2
#   පිලේ     3
# පිවිසීමට   1
# පිවිසෙන්න   2
# පිස්සුවක්   1
#  පිහිටා    1
#  පිහිටි    2
# පිහිටුවිය   3
# පිහිණුම්   1
#  පිහිනන    1
# පිහිනීමට   1
# පිහිනුම්   1
# පිළිකුත්තුව   1
#  පිළිගත    1
# පිළිගන්නවා   1
# පිළිතුර    1
# පිළිතුරක්   3
# පිළිතුරු   1
#  පිළිබඳ    7
# පිළිබඳව    5
# පිළිඹිබු   1
# පිළිසදර    1
# පිළිස්සී   4
# පිළිස්සීම්   1
#   පිළේ     1
# පීඑල්සී    1
#  පීඩයක්    1
#  පීඩාවට    1
#  පීවීසී    1
# පීසීආර්    1
#  පුංචි     2
#  පුංචී     1
#  පුතාගේ    2
# පුතෙකුගේ   5
# පුතෙකුත්   1
# පුද්ගලයකු   3
# පුද්ගලයන්   11
# පුද්ගලයන්ට   1
# පුද්ගලයා   1
# පුද්ගලයින්   6
# පුද්ගලයෙක්   1
# පුද්ගලයෙකු   1
# පුද්ගලයෙකුව   1
#  පුදුම     1
# පුනරුදයක්   1
# පුරවැසියන්   1
# පුරවැසියෙකු   2
#   පුරා     2
# පුරාගෙන    1
#  පුරාණ     1
#  පුරාවට    1
#  පුරුක     1
# පුරුද්ද    1
#  පුරුදු    2
# පුරෝකථනය   1
# පුලුවන්    6
# පුවත්පත    1
# පුවත්වලට   1
#   පුස්     1
#  පුහුණු    2
# පුහුණුවක්   1
#   පුළ      2
# පුළුවන්    4
# පුළුවන්කමක්   1
# පූජකයන්ගේ   1
#  පූර්ණ     1
#  පෘථිවි    1
#  පෙන්නන    1
# පෙන්නනවා   2
# පෙන්නුවත්   1
# පෙන්නුවේ   1
# පෙන්වනවා   1
#  පෙන්වා    3
# පෙන්වීම    1
# පෙන්ෂන්    1
#   පෙනී     4
#  පෙනීම     2
#   පෙනේ     1
# පෙම්වතිය   7
#   පෙර      5
#   පෙරට     1
# පෙරටුගාමී   2
#  පෙරදිග    5
#  පෙරමුණ    3
# පෙරමුණේ    2
# පෙරලන්න    1
# පෙරලුණාට   1
#  පෙරවරු    2
# පෙරවරුවේ   5
# පෙරවරුවේදී   1
#  පෙරුම්    1
#  පෙරේදා    1
# පෙළඹෙනු    1
#   පේන      1
#  පේනවනේ    1
#  පේනවා     2
#  පේන්න     1
#  පේන්නේ    1
#  පේමදාස    1
# පේරාදෙණිය   7
# පේරාදෙණියට   1
#  පොකුර     2
# පොකුරක්    2
# පොකුරෙන්   1
#   පොටෝ     3
#   පොත්     1
#   පොදු     2
#  පොදුජන    2
#   පොර      1
#   පොල්     5
# පොල්ගොල්ල   3
#  පොලිස්    21
# පොලිස්පති   1
# පොලිසිය    6
# පොලිසියට   1
# පොලිසියෙන්   1
# පොලිසියේදී   1
# පොලීසිය    1
# පොලීසියට   1
# පොලීසියෙන්   2
#   පොලු     1
#   පෝට්     1
#  පෝෂණය     1
# පෞද්ගලික   1
# ඵකතුවෙලා   1
#  බටහිර     2
# බඩගින්නෙ   2
#   බඩු      1
# බඩුඩීන්    1
#  බණ්ඩාර    1
# බණ්ඩාරගම   3
#   බත්      1
# බදියුද්දීන්   1
# බදියුදීන්   16
# බදියුදීන්ගෙ   1
# බදියුදීන්ගේ   9
#   බදු      1
# බදුර්දීන්   1
#   බන්      1
# බන්ගලදෙශයටත්   2
#  බන්දුල    7
# බන්දුලගෙන්   3
# බන්ධනාගාර   1
# බන්ධනාගාරගත   1
#  බබෙක්     1
# බම්බලපිටියේදී   1
#  බම්බූ     1
#    බය      1
#  බයික්     3
#    බර      2
#  බරපතල     1
#  බරපතළ     2
#    බල      2
#   බලං      1
#  බලද්දි    1
#  බලද්දී    1
# බලධාරීන්   3
#   බලන      1
#   බලන්     3
#  බලන්ට     1
#  බලන්න     4
#  බලපෑම්    3
#   බලපු     1
#   බලය      3
#   බලයට     1
#  බලවේගය    3
# බලවේගයේ    3
# බලහත්කාරයෙන්   1
# බල්ලෙක්    4
#  බලාගෙන    1
# බලාපොරොත්තු   5
# බලාපොරොත්තුව   2
#  බලේන්     1
#    බව      45
#   බවට      11
#   බවත්     2
#   බවය      1
#   බවයි     1
#   බස්      2
# බස්නාහිර   4
#  බස්සන     1
# බස්සන්න    1
#  බසින්     1
#  බහදූර්    1
#  බහුතරය    1
#  බහුලයි    1
# බ්රසීලයේ   1
# බ්රහස්පතින්දා   2
# බ්රිතාන්ය   1
#  බාකීර්    1
# බාගයක්වත්   1
#  බාගෙට     1
#  බාගෙම     1
#   බාධක     1
#   බාධා     2
#   බාර      2
# බාරගත්ත    1
#  බාරයේ     1
# බාලවයස්කරුවන්ගේ   1
# බාලවයස්කාර   1
# බාලවයස්කාරියක්   1
# බාස්කට්    1
#  බැංකු     1
# බැදුම්කරයක්   1
#  බැනර්     2
# බැනර්වල    1
#  බැනලා     1
#   බැරි     10
# බැරිවුනේ   2
# බැලන්ස්    1
#  බැලිම     1
# බැලිල්ලක්   1
#  බැලීම     1
#  බැලීමේ    1
# බැලුවත්    1
#  බැලුවම    1
#  බැලුවා    1
#  බැලෙන     1
#  බැවින්    3
#   බැස      1
#  බැසිල්    16
#   බැහැ     3
#    බෑ      11
#   බෑද      1
#   බෑනා     1
#   බිමට     9
#   බිම්     1
#  බිරිද     6
#  බිරිඳ     8
# බිරිඳගේ    1
#   බිලි     1
#  බිලියන    3
# බිලියනපතියො   1
# බිලියනයක   1
#  බිහිවූ    1
#    බී      1
#   බීපු     1
#   බුක්     1
# බුද්දික    1
#  බුද්ධි    1
# බුද්ධික    1
# බුද්ධිමත්   1
#   බුදු     1
#  බුස්ස     2
#  බෙදුනු    1
# බෙන්තොට    3
#  බෙල්ල     1
# බෙල්ලෙන්   1
#   බේබි     1
# බේරගන්න    1
#  බේරිලා    4
#  බේරෙන     1
#   බේරේ     5
#   බේස්     4
# බේස්බෝල්   2
#   බොන      1
#  බොන්නේ    1
# බොරැල්ල    1
#   බොරු     5
#   බොලං     1
#   බොහෝ     3
#  බොහෝම     1
#  බෝනස්     2
#   බෝන්     1
#  බෝම්බ     1
#  බෝරින්    1
#   බෝලය     1
#   බෝල්     5
#  භාගයක්    2
# භාග්යක්    1
#  භාණ්ඩ     1
#  භානුක     8
#  භාවිත     4
#  භාවිතා    1
#   භාෂා     1
#  භුමියේ    1
# භූමිකාවත්   1
# භූමියේදී   1
#    ම       9
#    මං      10
#   මංගල     3
#  මංගලට     1
#  මංචකේ     1
#   මංචී     1
# මගපෙන්වූ   1
#  මගින්     8
#  මගුල්     1
#   මගේ      3
# මඟහැරීමට   3
#    මට      4
#   මටත්     1
#  මට්ටමක    1
#  මට්ටමේ    1
#   මඩිය     1
#  මණ්ඩල     4
#  මණ්ඩලය    1
# මණ්ඩලයට    3
# මණ්ඩලයේ    2
#    මත      8
#   මතක      1
#   මතය      2
#   මතයක     6
#  මතවාද     2
# මත්කුඩු    2
# මත්තේගොඩ   1
# මත්ද්රව්ය   1
#  මතින්     1
# මතුවන්නට   1
# මතුවෙයි    2
# මධ්යස්ථ    1
# මධ්යස්ථානයක්   1
# මධ්යස්ථානයේ   2
#  මධුසංඛ    1
#  මන්ත්     1
# මන්ත්රි    2
# මන්ත්රිධුරය   1
# මන්ත්රිවරයාගේ   2
# මන්ත්රී    48
# මන්ත්රීවරයාගේ   1
# මන්ත්රීවරයාට   1
# මන්ත්රීවරයෙක්   1
# මන්ත්රීවරු   2
# මන්ත්රීවරුන්ගේ   1
# මන්ත්රීවරුන්ට   2
#   මන්ද     1
#  මන්දා     1
# මන්දිරයේ   4
#   මනාව     1
#  මනිෂ්     1
#   මනුෂ     3
# මනුස්සයා   1
# මනූෂගෙන්   1
#    මම      4
#  මයන්ත     1
#   මරණ     196
# මරණකරුවෙක   1
#   මරණය     2
#  මරණයක්    2
#  මරණයට     1
#   මරණෙ     1
#  මරණෙත්    1
#  මරදාන     1
#  මරනවා     3
#   මරලා     2
#  මර්දනය    2
#  මර්ධනය    1
#   මරා      4
#   මලල      12
#   මල්      1
# මල්වානෙ    1
#   මලා      1
#    මව      3
#  මව්රටට    1
#    මස      1
#   මසකට     1
#    මහ      6
# මහකොමසාරිස්වරු   1
#   මහජන     2
# මහජනතාව    3
#   මහත      1
# මහත්මියගේ   3
#  මහත්වූ    1
#   මහතා     39
# මහතාගෙන්   1
#  මහතාගේ    14
#  මහතාට     1
#  මහතාද     1
#   මහන      1
#  මහනුවර    3
#  මහපාරේ    2
#   මහපු     3
#  මහරගම     1
#   මහරජ     1
# මහරාජාගේ   1
#   මහලා     1
# මහාමාර්ග   1
#  මහිනද     1
#  මහින්ද    28
# මහින්දට    4
# මහින්දානන්දගෙන්   3
# මහෙස්ත්රාත්   2
# මහේන්ද්ර   1
# මහේස්ත්රාත්   1
#   මළල      3
#  මාකර්     1
# මාට්ටුවෙලා   1
#  මාතලේ     2
# මාත්රාව    1
# මාත්රාවක්   1
#  මාද්ය     1
# මාදිවෙල    1
#  මාධවී     1
#  මාධ්ය     12
# මාධ්යකරුවාගේ   1
#  මාධ්යය    1
# මාධ්යයක    1
# මාධ්යයෙන්   1
#   මානව     2
#  මානසික    2
# මානුෂීය    1
# මාමණ්ඩිය   1
#   මාමා     1
# මාර්ක්ස්වාදී   1
#  මාර්ග     2
# මාර්ගගත    1
# මාර්ගයෙන්   1
# මාර්ගස්ථ   1
# මාර්ගික    1
#   මාස      3
#   මාසය     1
# මාසයෙන්    1
# මාළිගාව    1
#   මැච්     1
#   මැටි     1
# මැටිතුමන්ටත්   1
# මැණිකක්    1
#  මැණික්    3
#   මැති     1
# මැතිතුමන්   1
# මැතිතුමන්ගේ   1
# මැතිතුමා   7
# මැතිතුමාගේ   4
# මැතිතුමාට   1
# මැතිඳුන්ටත්   2
# මැතිවරණය   1
# ...
#  ලබාදීම    1
# ලබාදීමට    1
# ලබාදුන්    1
# ලබාදුන්නේය   1
#  ලබාදෙන    1
# ලබාදෙනවා   1
# ලබාදෙමි    1
#   ලමයි     1
# ලමයින්ට    1
#   ලමා      2
# ලයිස්තු    1
#  ලස්සන     2
#    ලා      4
# ලාංකිකයන්   1
#  ලාංකීය    1
#  ලාංකේය    1
#  ලැජ්ජ     1
# ලැජ්ජාවක්   1
#  ලැබිල     1
#  ලැබීමට    1
# ලැබීමෙන්   1
#  ලැබීය     1
#   ලැබු     1
#  ලැබුණ     1
#  ලැබුණු    2
#  ලැබුණේ    1
#  ලැබුන     2
#   ලැබූ     4
# ලැබූවන්    1
#  ලැබෙන     3
# ලැයිස්තු   1
#   ලෑමේ     1
#  ලිංගික    3
# ලිංගෙම්බෝ   1
#   ලියන     2
# ලියනආරච්චි   1
#  ලියපු     1
#  ලිවුවේ    3
#    ලී      1
#  ලීල්ද     1
#    ලූ      1
#  ලෙඩෙක්    1
#   ලෙස      16
# ලෙසකින්    1
#  ලේකම්     8
# ලේකම්වරයකු   1
#  ලේඛකයා    1
#   ලේඛන     2
#   ලේසි     1
#  ලොක්කෝ    1
#   ලොකු     5
#  ලොකුම     1
#  ලොකූම     3
# ලොතරැයි    1
#   ලොව      7
#  ලොවටම     1
#   ලොවම     1
#   ලෝක      5
#   ලෝකඩ     3
# ලෝකයෙන්    2
#  ලෝකයේ     1
#   ලෝකෙ     2
#  ලෝකෙට     1
#  ලෝකෙටම    1
#   ලෝකේ     1
# ලෝලින්ට    1
# ලෝලින්ද    1
#  ලෝලියා    1
#  ලෝලීන්    1
# ලෝලීන්ගේ   1
# ලෝලීන්ද    1
#    ව       1
#   වංචා     6
# වංචාකාරයො   1
#  වංචාව     1
# වංචාවන්    2
# වකුගඩුරෝග   2
#    වග      3
#   වගක්     1
# වගකිවයුතුයි   2
#   වගයි     1
#  වගවීම     3
#   වගාව     1
#   වගෙ      1
#   වගේ      26
#   වගේද     1
#   වගේම     6
#  වගේමයි    1
#    වච      1
#   වචන      1
#    වට      1
#   වටයට     1
#  වටයන්න    1
#   වටයේ     2
#  වටයේදී    1
#  වට්ටපු    1
# වට්ටුවාකල්   1
# වට්ටුවාක්කල්   2
#  වටිනා     1
# වටිනාකමකින්   1
# වටිහතළිහකට   1
#   වටේ      1
#   වඩා      5
#  වඩාත්     1
#  වත්තේ     1
#  වතාවෙම    1
#  වදින්න    1
#    වන      46
#   වනදා     6
#  වනදාය     1
#   වනවා     1
#  වනවිට     4
#  වන්චාව    1
# වන්නිනායක   1
#  වන්නේ     4
#  වනිඳු     1
# වඳවෙනබව    1
#  වමතින්    1
# වමාරනවා    1
#   වයස      6
#   වයස්     1
#  වයිට්     2
#  වයිරස්    1
#   වරක්     2
#   වරණය     1
# වරදකරුවන්   1
#  වරදක්     1
# වරද්දපු    1
# වරප්රසාද   1
#  වර්ජනය    1
# වර්ජනයට    1
# වර්තමාන    1
#  වර්ධනය    2
# වර්ල්ඩ්    1
#  වර්ෂයේ    1
#   වරාය     1
#   වරු      1
#    වල      5
#   වලකා     1
#   වලට      12
#   වලදී     1
# වල්කන්ට්රිවල්ලෝ   1
#  වලින්     6
#   වවං      1
#  වශයෙන්    5
#    වස      1
#  වසංගත     6
#  වසංගතය    1
#  වසංගතේ    1
#  වසන්තය    1
#   වසමේ     1
#   වසර      3
#   වසරේ     2
#  වස්ති     1
#  වස්තු     1
#   වසා      1
#  වහනවා     1
#  වහන්න     1
#   වහල      1
#   වහාම     1
# ව්යවස්ථාවේ   1
#  ව්යාජ     2
# ව්යාප්තියක්වත්   1
# ව්යාප්තියේ   1
# ව්යාපෘතියක   1
# ව්යාපෘතියක්   1
# ව්යාපෘතියේ   1
#  ව්සින්    6
#   වාගේ     1
#  වාට්ටු    1
#   වාර      1
#  වාර්තව    2
# වාර්තවක්   2
#  වාර්තා    47
# වාර්තාකර   1
# වාර්තාද    1
# වාර්තාව    2
# වාර්තාවේ   6
# වාසගමකුත්   1
#  වාසනාව    2
# වාසිදායක   1
#   වාහන     7
# වාහනයක්    1
# වැක්සීන්   1
#  වැටුප්    9
# වැටෙනවා    2
#   වැටේ     5
#   වැඩ      7
# වැඩකරණරටක්   1
#  වැඩක්     9
# වැඩකාරකමට   1
#   වැඩට     2
# වැඩවර්ජන   1
# වැඩසටහන    2
# වැඩසටහන්   1
#   වැඩි     55
# වැඩිකරන්න   2
# වැඩිකළේ    1
# වැඩිකිරීම   1
# වැඩිදුර    2
# වැඩිදුරටත්   1
#  වැඩිම     2
#  වැඩියි    5
# වැඩිවෙන්නෙ   1
# වැඩිවෙලා   1
#   වැඩේ     2
#   වැදග     1
#  වැදගත්    1
# වැදගත්කම   1
# වැදගත්ම    1
# වැදගත්ය    1
#   වැනි     4
#  වැනිදා    2
#  වැනිස්    1
#   වැය      3
#  වැරදි     2
# වැරදියි    2
# වැරදිලාවත්ද   1
# වැරදුනු    2
#  වැලඳීම    1
# වැලලාගනී   5
# වැල්ලවත්ත   2
#   වැව      2
# වැසිකිලියේ   6
# වැසියන්    3
# වැළදිමෙන්   2
# වැළලාගෙන   2
#   වෑන්     1
# විකල්පයක්   2
# වික්රමසිංහලා   1
#  විකාශය    1
# විකිණීමේ   1
#  විකුණන    1
#  විකෘති    1
# විජේරත්න   2
#   විට      12
#   විතර     3
#  විතරයි    3
# විතාරණයි   1
#  විද්යා    2
# විද්යාතන   1
# විද්යාතනය   1
# විද්යාව    1
# විද්යුත්   1
# විදානගමගේ   1
#  විදින     1
#  විදිය     2
#  විදියට    2
#  විදිහ     1
#  විදිහට    3
# විදුරගේ    1
#  විදුලි    1
# විදුහල්පති   7
#  විදෙස්    5
#  විදේශ     4
# විදේශයන්හි   2
#  විධායක    1
# විධිමත්    2
#   විනය     5
# වින්දිතයා   1
#  විනාශ     1
# විනිවිද    1
#  විනෝද     1
#  විඳපු     1
#  විපක්ෂ    1
# විභාගත්    1
#   විමද     1
# විමර්ශන    6
#  විමල්     10
#   විමූ     1
#   විය      5
#  වියදම්    2
# වියමෙලෙස   2
# වියහැකි    1
# විරුද්ධව   3
# විරුද්ධවාදීන්   1
#  විරුවා    2
# විරෝධතා    1
# විරෝධතාවයට   2
# විරෝධතාවයෙන්   1
#  විරෝධය    4
# විරෝධයෙන්   1
# විරෝධිව    1
#  විරෝධී    2
# විල්පත්තු   4
# විල්පත්තුවත්   1
#  විලාසය    1
# විවාදයට    3
#  විවාහ     1
# විවිධත්වය   1
#  විවෘත     10
# විශ්රාම    1
# විශ්වවිද්යාල   1
# විශ්වවිද්යාලයේ   1
# විශ්වාස    1
#  විශාල     5
# විශිෂ්ට    2
# විශිෂ්ටතම   1
# විශුද්ධි   1
# විශුද්ධිකරණය   1
#  විශේෂ     7
#  විශේෂඥ    2
# විශේෂඥයින්   2
# විශේෂත්වය   1
# විශේෂයෙන්   3
#  විෂමතා    1
# විෂමතාව    1
# විෂමතාවය   1
#  විසන්     1
# විසඳන්න    1
# විසඳුමක්   1
#  විසල්     1
#  විස්තර    36
# විස්වාස    1
# විස්වාසය   1
# විස්සයි    3
#   විසා     6
#   විසි     1
# විසිකරලා   1
#  විසින්    31
# විහාරස්ථාන   2
# විහිළුවක්   1
# විහිළුවකි   1
#    වී      18
#  වීඩියෝ    3
#   වීදි     1
#   වීම      6
#  වීමක්     1
#   වීමට     2
#  වීමත්     4
#  වීරවංශ    4
# වීරසේකර    1
#    වු      1
#  වුණත්     1
#  වුණාම     1
#   වුණු     1
#   වුණේ     2
#   වුන      2
#  වුනත්     1
#   වුනා     1
#   වුනු     1
#  වුනොත්    1
# වුවමනාවක්   1
#    වූ      23
# වෘත්තීය    1
#    වෙ      2
#  වෙඩින්    1
#   වෙත      4
#  වෙතත්     1
#   වෙන      9
#  වෙනවා     3
#  වෙනසක්    3
#  වෙනස්     2
# වෙනස්කොට   1
#   වෙන්     1
# වෙන්කරන    1
#  වෙන්ඩ     1
#  වෙන්න     8
# වෙන්නැති   1
#  වෙන්නෙ    5
#  වෙන්නේ    4
#   වෙනි     1
#  වෙනුවට    2
# වෙනුවෙන්   10
#  වෙමින්    5
#   වෙයි     23
#   වෙලා     14
#  වෙලාවේ    1
#   වෙළඳ     1
#  වෙළඳාම    1
#  වෙළෙඳ     3
#    වේ      5
# වේගයෙන්ම   1
#   වේදී     1
# වේලාවකට    1
# වේලාවෙන්   1
#   වේවා     1
#  වෛද්ය     6
# වෛද්යවරයා   1
# වෛද්යවරයෙකු   1
#  වෛරසය     2
# වොලිබෝල්   2
# ශක්තියක්   1
# ශල්යවෛද්ය   2
# ශ්රිමතානන්   1
# ශ්රිලංකා   1
#   ශ්රී     35
# ශ්රීයානි   2
# ශ්රීලංකන්   2
# ශ්රීලංකා   2
# ශ්රීලනිප   3
# ශ්රීලනිපයට   2
# ශ්රීලාංකික   2
#   ශානක     1
# ශානක්කියන්   1
#  ශිකර්     1
#  ශික්ෂණ    5
# ශිරන්ති    2
# ශිල්පිණී   1
# ශිල්පිනී   1
#  ශිල්පී    1
#  ශීර්ෂය    1
# ශීර්ෂයෙන්   1
#   ශූර      2
#  ශූරතා     1
#  ශූරිය     1
#   ශූරී     1
#   ෂර්      1
#  ෂුවර්     1
#    ෂෝ      1
#    ස       1
# සංකීර්ණයේ   1
# සංකුලතාවය   2
# සංඛ්යාව    18
# සංඛ්යාවක්   1
# සංගණනයක්   2
#  සංගමයේ    2
#  සංගම්     4
#  සංගමේ     1
#  සංචාරක    11
#  සංචාරය    1
# සංචාරයක්   1
# සංවර්ධන    4
# සංවර්ධනය   4
# සංවර්ධනයේ   2
#  සංවාදය    2
# සංවිධාන    1
# සංවිධානය   4
# සංවිධානාත්මක   1
# සංවිධායක   1
# සංවිධායකයින්   1
#  සංවෘත     1
# සංස්කෘතිය   1
# සංස්ථාවේ   1
# සංහිඳියාව   1
#   සකස්     1
#   සකසා     1
#  සක්රිය    1
# සක්රියව    1
# සඟරාවලට    1
# සජබපාමන්ත්රී   1
# සජ්ජායනය   1
#  සජිත්     6
# සජිත්ගෙන්   3
#   සජී      1
#  සජීවීව    1
#   සටන      1
#   සටන්     2
#   සටහන     2
#  සටහනක්    2
#  සටහන්     1
#  සටහනේ     4
#  සතයක්     1
# සත්කාරක    2
# සත්ගුණවත්   1
#  සත්තයි    1
#   සත්ය     1
# සත්යයකි    1
#   සති      1
#   සතිය     1
#  සතියේ     1
#   සතු      1
#  සතුටුට    1
#  සදහන්     1
#   සදහා     6
#  සදහායි    1
#   සධීර     1
# සන්තකයේ    1
#  සන්ධාන    1
#    සඳ      1
#  සඳහන්     4
#   සඳහා     32
#  සඳුදා     6
#  සඳුදාට    1
# සපයගන්න    1
#  සපයනවා    1
#  සපයන්න    1
#  සබඳතා     2
#  සබෞද්ධ    1
#   සභා      1
#  සභාපති    1
#    සම      1
#   සමග      14
#   සමගි     6
#  සමගින්    1
#   සමඟ      10
#  සමත්ව     2
# සමන්විත    1
#   සමයේ     1
#  සමරනවා    1
# සමරවික්රම   1
#  සමරවීර    3
#  සමස්ත     14
#  සමස්තය    1
#   සමහර     2
#  සම්පත්    1
# සම්පාදන    2
# සම්පුර්ණ   1
# සම්පූර්ණයෙන්ම   3
# සම්බන්ද    1
# සම්බන්ධ    3
# සම්බන්ධකතාවය   1
# සම්බන්ධයක්   1
# සම්බන්ධයෙන්   12
# සම්බන්ධව   1
# සම්බන්ධීකරණ   1
#  සම්මාන    3
# සම්මානය    2
# සම්මානයෙන්   1
# සම්මුඛසාකච්චාවකදී   1
#  සමාගම     2
#  සමාගම්    1
#  සමාගමේ    1
#   සමාජ     3
#  සමාජගත    1
#  සමාජයට    1
# සමාජවාදී   1
#  සමානව     1
# සමානාත්මතාවය   1
# සමාලෝචනය   1
#  සමිති     1
# සමීක්ෂණයටකට   1
#   සමීප     1
# සමුද්රජීවී   1
#  සමූහයේ    1
# සයිලන්ස්   1
#   සරණ      7
#   සරත්     1
#  සරත්ගේ    1
#   සරලව     1
#   සර්      3
#   සලකා     2
#  සල්ලි     5
# සල්ලිවලට   1
#   සවස      1
#  සවාරිය    1
# සවාරියේ    1
#  සසඳන්න    1
#   සසරේ     1
#    සහ      67
#   සහගත     1
#  සහතික     3
#  සහතිකය    1
#  සහභාගි    2
#  සහභාගී    3
# සහභාගීත්වයෙන්   1
#  සහයෝගය    1
# සහයෝගීතාව   1
# සහයෝගීතාවය   1
#   සහල්     1
# සහසුද්දෙන්ම   1
#   සහිත     3
#  සහිතයි    2
# සහෝදරයා    1
# සහෝදරයාට   1
# ස්කේට්බොඩිං   1
#  ස්කෝල     1
# ස්ටාලින්   4
# ස්ටාලීන්   1
# ස්ටේඩියම්   1
#  ස්ත්රී    3
# ස්ත්රීපුරුෂභාවය   1
# ස්තුතිය    1
#  ස්ථාන     3
#  ස්ථානය    2
# ස්ථානයක    1
# ස්ථානයකින්   1
# ස්ථානයට    2
# ස්ථානයේ    1
# ස්මාට්ෆෝන්   1
# ස්වභාවික   1
#  ස්වයං     5
# ස්වර්ණමාලි   1
# ස්වර්ණමාලී   1
# ස්වාධීන    1
# සාකච්ඡා    4
# සාකච්ඡාව   6
# සාකච්ඡාවක   1
# සාකච්ඡාවක්   9
# සාකච්ඡාවට   1
# සාකච්ඡාවේදී   1
#   සාගර     1
# සාගරගෙන්   1
#  සාගලද     1
#  සාඩින්    1
# සාත්තරත්   1
#   සාද      1
#  සාදයකට    1
# සාදරයෙන්   1
#   සාධක     1
# සාධරණයක්   2
# සාපරාධී    1
# සාමාජිකයන්   1
# සාමාජිකයින්   1
# සාමාජිකයින්ට   1
# සාමාජිකයෙකු   1
# සාමාන්යකරණය   1
#  සාර්ථක    1
# සාර්ථකයි   3
# සාර්ථකව    1
#  සැකකරු    2
# සැකකරුවකු   2
# සැකකරුවන්   2
# සැකකරුවෙක්   2
# සැකකරුවෙකු   1
# සැඟවීමේ    1
#   සැප      1
#  සැපයූ     1
# සැප්තැම්බර්   3
#   සැබෑ     3
#   සැමට     1
# සැම්සන්    1
#  සැරිය     1
# සැලකීමේ    1
#  සැලකෙන    1
# සැලසුම්    1
# සැලැස්මක්   3
# සැලැස්මට   1
# සැළසුම්    2
#   සෑම      1
#   සෑම්     1
#  සෑහෙන     2
# සිංගප්පූරුව   1
# සිංගප්පූරුවේ   1
#  සිංදු     2
#   සිංහ     1
#  සිංහල     1
# සිකුරාදා   1
#   සිට      9
#   සිටම     1
#   සිටි     8
#  සිටිති    1
#  සිටින     12
# සිටින්නේ   1
# සිටිමින්   2
#  සිටිය     2
# සිටියදී    2
#  සිටියි    2
# සිටියේජූලි   1
# සිටියේද    1
#   සිටී     3
#  සිතමු     1
# සිද්ධිය    1
# සිද්ධියට   1
# සිද්ධියේ   1
#   සිදු     14
#  සිදුකර    2
# සිදුකරන    2
#  සිදුකල    3
#  සිදුකළ    1
#  සිදුව     2
# සිදුවිය    2
# සිදුවීමක්   1
#  සිදුවු    3
# සිදුවුණු   1
#  සිදුවූ    5
# සිදුවෙමින්   1
#  සිනමා     4
# සින්දුව    1
# සිප්කිරිපෙවූ   1
#   සිය      4
# සියදිවි    1
#  සියල්ල    3
# සියල්ලන්ට   1
#  සියලු     8
# සියලුදෙනාට   2
#  සියලූම    1
# සිරදඬුවම්   1
#  සිරාවට    1
#  සිරිත     1
# සිරිපාල    2
#  සිරිමා    1
# සිරිසේන    2
#  සිරුර     11
#  සිරුරු    1
#  සිලබස්    1
#  සිල්වා    6
#   සිව්     1
# සිව්දෙනා   1
#  සිව්වන    1
#  සිවිල්    4
#  සිවුරු    1
# සිස්ටම්    1
#  සිළුව     1
#    සී      1
#   සීමා     1
#  සීමාව     2
#  සීමාවේ    1
#  සීයක්     1
#  සීසන්     1
# සුදර්ශනී   2
# සුදර්ශිනී   1
#   සුදු     1
#  සුදුසු    1
# සුදුසුකම්   2
#  සුනන්ද    1
#  සුන්දර    1
# සුනාමියෙන්   1
# සුපිරිම    1
# සුපුරුදු   1
#   සුබ      1
#   සුර      1
# සුරක්ෂිතතාව   1
# සුරතින්    3
# සුර්යකුමාර්   1
#   සුව      1
# සුවදුක්    1
#   සුවය     3
#  සුවවී     5
# සුසන්තිකා   1
#  සුසාන     1
# සුහදතාව    1
# සූදානම්    4
# සූදානමින්   2
#   සෙට්     2
# සෙට්ටෙක    1
# සෙනසුරාදා   2
# සෙන්ටර්    1
# සෙල්ලන්ද   1
#  සෙල්ෆි    1
#    සේ      2
#   සේරම     2
#   සේවක     1
# සේවකයන්    1
# සේවකයන්ට   1
#  සේවකයො    1
#   සේවය     4
#  සේවයක්    1
#  සේවයේ     7
#   සේවා     12
#  සේවාව     2
# සේවාවක්    1
#  සොත්ති    2
#  සොනික්    2
#   සොයා     1
# සොයාබැලෙන   1
# සොරාගෙන    1
#  සොහොන     1
# සොහොයුරාට   1
#    සෝ      1
#  සෝෂල්     1
#  සෞඛ්ය     24
#  සෞඛ්යය    5
# සෞභාග්යය   1
#    හට      12
#  හතරක්     2
#  හතරටම     1
#  හතරවටේ    2
#  හතරවන     1
#  හදන්න     2
#  හදන්නේ    3
#   හදපු     1
#   හදලා     2
# හදාගන්න    1
#  හඳුනන     1
#  හඳුනා     6
# හඳුනාගත්   4
# හඳුනාගනී   5
# හඳුනාගැනීමට   1
#   හමන්     2
# හම්බන්තොට   1
# හම්බවුණා   1
# හම්බවුනත්   1
# හම්බවෙමු   1
# හම්බවෙමුජය   1
# හම්බුවෙනවා   1
# හම්බුවෙයි   1
#  හමාරයි    1
#  හමුදා     5
#  හමුදාව    1
# හමුදාවක්   1
# හමුදාවේ    1
#   හමුව     1
#  හමුවක්    3
#  හමුවට     2
#  හමුවී     2
# හමුවීමට    1
#  හමුවූ     3
# හමුවෙති    1
# හමුවෙන්න   1
# හමුවෙයි    11
# හමුවේදී    1
#   හඹා      1
#    හය      1
#   හයක්     5
#  හයියෝ     1
# හයිරයිඩස්   1
# හයිසින්ත්   2
#   හරක්     1
#   හර්ෂ     2
#   හරි      7
#  හරිනම්    1
#   හරිම     1
#  හරියට     2
# හරියන්නේ   1
#  හරීන්     9
#  හරීම්     1
#   හවසට     1
#  හවුස්     1
#  හසරංග     1
#   හ්ම්     2
#    හා      16
# හාදයෙක්    1
#  හානිකර    1
# හාමදුරුවන්ගෙන්   1
# හාමදුරුවෝ   1
# හාමුදුරුවන්   1
# හාමුදුරුවරුන්ගේ   1
# හාර්දික්   1
#   හාල්     5
#    හැ      1
#   හැකි     13
#  හැකිය     1
# හැකියාවක්   1
#  හැඟීම     1
#   හැට      1
# හැටගානක්   1
#  හැටන්     1
# හැට්ටකටු   1
#   හැටි     4
#  හැටිද     1
#  හැටියට    2
#  හැදිලා    3
# හැදුනොත්   1
#  හැදුවා    1
# හැප්පෙන්නෙ   1
#  හැබැයි    1
#   හැම      3
# හැමකෙනෙක්මවගේ   1
#  හැමදාම    1
# හැමදාමත්   1
#  හැමදේම    1
# හැමනායකයෙක්ම   1
# හැමෝගෙම    1
#  හැමෝටම    2
#  හැමෝම     2
#   හැර      1
#  හැරයාම    1
#  හැරලා     1
#  හැරියේ    1
# හැවරිදි    1
# හැවිරිදි   8
# හැවිරිදිවියේ   2
#    හි      5
#  හිංසනය    1
#  හිංසා     1
#  හිකුනට    1
#   හිගා     1
#   හිඟන     1
#  හිටපු     34
#  හිටිය     2
# හිටියනම්   1
#  හිටියා    1
#  හිතකර     1
#  හිතන්     1
#  හිතන්න    2
# හිතන්නකො   1
# හිතන්නෙ    1
# හිතන්නේ    1
#  හිතවත්    1
# හිතවතෙක්   1
# හිතාමතා    1
#  හිතින්    1
#  හිතුණේ    1
#  හිතුන     1
#  හිතුනා    1
#  හිතුවා    1
#  හින්දම    1
#   හිමි     4
# හිමිකම්    1
# හිමියන්    2
#   හිරු     1
#  හිලව්     1
# හිශාලිනීගේ   1
#   හිස      5
#    හී      1
# හීනමානෙ    1
#  හුංගම     1
#  හුඟක්     1
#  හුත්තො    1
#   හුදු     1
# හුවමාරුව   1
#   හුවා     1
#   හෙට      7
#   හෙද      1
#   හෙන      3
#  හෙනගහන    1
# හෙරොයින්   5
# හෙලිදරව්ව   1
#  හෙවත්     1
#  හෙළයන්    1
# හෙළිකරයි   2
# හෙළිවෙයි   1
#  හෙළිවේ    1
# හෙළුවෙන්ම   1
#  හේතුව     1
# හේතුවක්    1
# හේතුවෙන්   4
# හේමසිරි    1
#   හොද      1
#   හොදම     2
#   හොදෙ     1
#   හොඳ      2
#   හොඳට     2
#   හොයල     1
# හොරොයින්   1
# හොස්පිටල්ස්   2
#    හෝ      6
#    ළම      1
#   ළමයි     2
#  ළමයෙක්    1
#   ළමයෝ     2
#  ළමායි     1
# ෆ්ලෙක්ස්   1
#  ෆායිස්    1
# ෆින්ලන්ත   1
# ෆින්ලන්තයේපොත්පත්   1
#  ෆිල්ම්    1
#   ෆේස්     1
#   ෆෝම්     2

# %%
stopword = []
for w in wd:
    if(wd[w]>10):
        stopword.append(w)
print(stopword)
# Out:
# ['අග්රාමාත්ය', 'අඩු', 'අතර', 'අත්අඩංගුවට', 'අද', 'අධ්යක්ෂ', 'අනුව', 'අපරාධ', 'අපි', 'අපේ', 'අමාත්ය', 'අවසන්', 'ආසාදිත', 'ආසාදිතයින්', 'ඇත', 'ඇති', 'ඇමති', 'ඇයි', 'ඉඩම්', 'ඊයේ', 'උළෙලේ', 'එක', 'එන්නත', 'ඒ', 'ඔලිම්පික්', 'ඔහු', 'කර', 'කරන', 'කරනවා', 'කරන්න', 'කරයි', 'කළ', 'ක්', 'ක්රීඩා', 'කියලා', 'කිරීම', 'කොරෝනා', 'කොවිඩ්', 'ගණන', 'ගැන', 'ගිය', 'ගුරු', 'ගුවන්', 'ගෙන', 'ගෝඨාභය', 'ජනාධිපති', 'ජාතික', 'ජූලි', 'ට', 'තමයි', 'තර්ජන', 'තව', 'තවත්', 'තහවුරු', 'තිබේ', 'තුළ', 'ද', 'දැන්', 'දැරියගේ', 'දින', 'දිනයේ', 'දී', 'දෙවන', 'නම්', 'නව', 'නාමල්', 'නාවික', 'නැති', 'නැහැ', 'නෑ', 'නිදහස්', 'නිරෝධායනයට', 'නිවසේ', 'නිසා', 'පත්', 'පදක්කම්', 'පරීක්ෂණ', 'පරීක්ෂණය', 'පවසයි', 'පශ්චාත්', 'පාර්ලිමේන්තු', 'පැවති', 'පුද්ගලයන්', 'පොලිස්', 'බදියුදීන්', 'බව', 'බවට', 'බැසිල්', 'බෑ', 'මන්ත්රී', 'මරණ', 'මලල', 'මහතා', 'මහතාගේ', 'මහින්ද', 'මාධ්ය', 'මුදල්', 'මෙරට', 'මෙහෙකාර', 'මේ', 'යන', 'යි', 'රට', 'රාජපක්ෂ', 'රාජ්ය', 'රිෂාඩ්', 'ලංකා', 'ලංකාව', 'ලංකාවේ', 'ලබා', 'ලෙස', 'වගේ', 'වන', 'වලට', 'වාර්තා', 'වැඩි', 'විට', 'විස්තර', 'විසින්', 'වී', 'වූ', 'වෙයි', 'වෙලා', 'ශ්රී', 'සංඛ්යාව', 'සංචාරක', 'සඳහා', 'සමග', 'සමස්ත', 'සම්බන්ධයෙන්', 'සහ', 'සිටින', 'සිදු', 'සිරුර', 'සේවා', 'සෞඛ්ය', 'හට', 'හමුවෙයි', 'හා', 'හැකි', 'හිටපු']

# %%
# def clean_text(text):
#     tokens = nltk.word_tokenize(text)
#     tokens = " ".join([word for word in tokens if word not in stopword])
#     return tokens

# %%
# data['remove_stopwords'] = data['cleaned_msg'].apply(lambda x: clean_text(x))
# data.head()

# %%
############################ Stop Word removing Method 2 - using predefined stop words ####################################

# %%
stopwordsreader = open('StopWords', 'r', encoding='utf-8')
reader = csv.reader(stopwordsreader)

swords = []
for row in reader:
    swords.append(row[0])
print(swords)
# Out:
# ['සහ', 'සමග', 'සමඟ', 'අහා', 'ආහ්', 'ආ', 'ඕහෝ', 'අනේ', 'අඳෝ', 'අපොයි', 'අපෝ', 'අයියෝ', 'ආයි', 'ඌයි', 'චී', 'චිහ්', 'චික්', 'හෝ\u200d', 'දෝ', 'දෝහෝ', 'මෙන්', 'සේ', 'වැනි', 'බඳු', 'වන්', 'අයුරු', 'අයුරින්', 'ලෙස', 'වැඩි', 'ශ්\u200dරී', 'හා', 'ය', 'නිසා', 'නිසාවෙන්', 'බවට', 'බව', 'බවෙන්', 'නම්', 'වැඩි', 'සිට', 'දී', 'මහා', 'මහ', 'පමණ', 'පමණින්', 'පමන', 'වන', 'විට', 'විටින්', 'මේ', 'මෙලෙස', 'මෙයින්', 'ඇති', 'ලෙස', 'සිදු', 'වශයෙන්', 'යන', 'සඳහා', 'මගින්', 'හෝ\u200d', 'ඉතා', 'ඒ', 'එම', 'ද', 'අතර', 'විසින්', 'සමග', 'පිළිබඳව', 'පිළිබඳ', 'තුළ', 'බව', 'වැනි', 'මහ', 'මෙම', 'මෙහි', 'මේ', 'වෙත', 'වෙතින්', 'වෙතට', 'වෙනුවෙන්', 'වෙනුවට', 'වෙන', 'ගැන', 'නෑ', 'අනුව', 'නව', 'පිළිබඳ', 'විශේෂ', 'දැනට', 'එහෙන්', 'මෙහෙන්', 'එහේ', 'මෙහේ', 'ම', 'තවත්', 'තව ', 'සහ', 'දක්වා', 'ට', 'ගේ', 'එ', 'ක', 'ක්', 'බවත්', 'බවද', 'මත', 'ඇතුලු', 'ඇතුළු', 'මෙසේ', 'වඩා', 'වඩාත්ම', 'නිති', 'නිතිත්', 'නිතොර', 'නිතර', 'ඉක්බිති', 'දැන්', 'යලි', 'පුන', 'ඉතින්', 'සිට', 'සිටන්', 'පටන්', 'තෙක්', 'දක්වා', 'සා', 'තාක්', 'තුවක්', 'පවා', 'ද', 'හෝ\u200d', 'වත්', 'විනා', 'හැර', 'මිස', 'මුත්', 'කිම', 'කිම්', 'ඇයි', 'මන්ද', 'හෙවත්', 'නොහොත්', 'පතා', 'පාසා', 'ගානෙ', 'තව', 'ඉතා', 'බොහෝ', 'වහා', 'සෙද', 'සැනින්', 'හනික', 'එම්බා', 'එම්බල', 'බොල', 'නම්', 'වනාහි', 'කලී', 'ඉඳුරා', 'අන්න', 'ඔන්න', 'මෙන්න', 'උදෙසා', 'පිණිස', 'සඳහා', 'අරබයා', 'නිසා', 'එනිසා', 'එබැවින්', 'බැවින්', 'හෙයින්', 'සේක්', 'සේක', 'ගැන', 'අනුව', 'පරිදි', 'විට', 'තෙක්', 'මෙතෙක්', 'මේතාක්', 'තුරු', 'තුරා', 'තුරාවට', 'තුලින්', 'නමුත්', 'එනමුත්', 'වස්', 'මෙන්', 'ලෙස', 'පරිදි', 'එහෙත්']

# %%
def remove_stop_words(text):
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in swords]
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
data['remove_stopword'] = data['cleaned_msg'].apply(lambda x: remove_stop_words(x))
data.head()
# Out:
#     ID      User  \
# 2  0.0  1.42E+18
# 3  1.0  1.42E+18
# 4  2.0  1.42E+18
# 5  3.0  1.42E+18
# 6  4.0  1.42E+18
#
#                                                                                                                                                                 FULL_TEXT  \
# 2                                                          @Srihandalk @kajuwattha හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්‍යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ. ?
# 3                                                                 @GotabayaR ද්විපාර්ශවික එකඟතාව පරිදි, ජන ජීවිත සහ සෞඛ්‍යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා ?
# 4                                                   @FCDOGovUK @UKinSriLanka කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි?
# 5      @WHOSriLanka @WHOSEARO @UNSriLanka @MoH_SriLanka @HPBSriLanka @DMRCASriLanka @ACJUNEWS @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුර?
# 6  @WHOSriLanka @UNSriLanka @WHOSEARO @WHO @MoH_SriLanka @HPBSriLanka @RajapaksaNamal @MCND_LKA @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට ය?
#
#         CREATED_AT LIKE COUNT FOLLOWERS COUNT     LABEL  \
# 2   7/29/2021 2:40          1            1433     Other
# 3  7/27/2021 10:40         10           13898  Politics
# 4  7/25/2021 20:56          0              87     Other
# 5  7/25/2021 20:53          0              87     Other
# 6  7/25/2021 20:52          1              87     Other
#
#                                                                                 cleaned_msg  \
# 2        හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3  ද්විපාර්ශවික එකඟතාව පරිදි ජන ජීවිත සහ සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා
# 4         කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                                     කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                       කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට ය
#
#                                                                      remove_stopword
# 2        හාමුදුරුවරුන්ගේ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3       ද්විපාර්ශවික එකඟතාව ජන ජීවිත සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය
# 4  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                              කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට

# %%
########################################## Stemming ##################################################

# %%
stem_dict = open("stem_dictionary.txt", "r", encoding='utf-8')
stem_dict = map(lambda s: s.strip(), stem_dict)

stem_dictionary = {}

for s in stem_dict:
    s = s.split("\t")
    stem_dictionary[s[0]] = s[1]

# %%
def stemming_words(text):
    tokens = nltk.word_tokenize(text)
    for k, v in enumerate(tokens):
        tokens[k] = stem_dictionary.get(v, v)
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
data['stemming_words'] = data['remove_stopword'].apply(lambda x: stemming_words(x))
data.head()
# Out:
#     ID      User  \
# 2  0.0  1.42E+18
# 3  1.0  1.42E+18
# 4  2.0  1.42E+18
# 5  3.0  1.42E+18
# 6  4.0  1.42E+18
#
#                                                                                                                                                                 FULL_TEXT  \
# 2                                                          @Srihandalk @kajuwattha හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්‍යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ. ?
# 3                                                                 @GotabayaR ද්විපාර්ශවික එකඟතාව පරිදි, ජන ජීවිත සහ සෞඛ්‍යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා ?
# 4                                                   @FCDOGovUK @UKinSriLanka කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි?
# 5      @WHOSriLanka @WHOSEARO @UNSriLanka @MoH_SriLanka @HPBSriLanka @DMRCASriLanka @ACJUNEWS @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුර?
# 6  @WHOSriLanka @UNSriLanka @WHOSEARO @WHO @MoH_SriLanka @HPBSriLanka @RajapaksaNamal @MCND_LKA @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට ය?
#
#         CREATED_AT LIKE COUNT FOLLOWERS COUNT     LABEL  \
# 2   7/29/2021 2:40          1            1433     Other
# 3  7/27/2021 10:40         10           13898  Politics
# 4  7/25/2021 20:56          0              87     Other
# 5  7/25/2021 20:53          0              87     Other
# 6  7/25/2021 20:52          1              87     Other
#
#                                                                                 cleaned_msg  \
# 2        හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3  ද්විපාර්ශවික එකඟතාව පරිදි ජන ජීවිත සහ සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා
# 4         කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                                     කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                       කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට ය
#
#                                                                      remove_stopword  \
# 2        හාමුදුරුවරුන්ගේ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3       ද්විපාර්ශවික එකඟතාව ජන ජීවිත සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය
# 4  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                              කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට
#
#                                                                     stemming_words
# 2          හාමුදුරුවරු සියලූම පූජකයන්ගේ මානසික සෞඛ්යය සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3      ද්විපාර්ශවික එකඟතා ජන ජීවිත සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය
# 4  කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                              කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                  කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට

# %%
######################### Remove Duplicates from dataset #################

# %%
data.drop_duplicates(subset='stemming_words',keep='first',inplace = True)
data.head()
# Out:
#     ID      User  \
# 2  0.0  1.42E+18
# 3  1.0  1.42E+18
# 4  2.0  1.42E+18
# 5  3.0  1.42E+18
# 6  4.0  1.42E+18
#
#                                                                                                                                                                 FULL_TEXT  \
# 2                                                          @Srihandalk @kajuwattha හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්‍යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ. ?
# 3                                                                 @GotabayaR ද්විපාර්ශවික එකඟතාව පරිදි, ජන ජීවිත සහ සෞඛ්‍යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා ?
# 4                                                   @FCDOGovUK @UKinSriLanka කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි?
# 5      @WHOSriLanka @WHOSEARO @UNSriLanka @MoH_SriLanka @HPBSriLanka @DMRCASriLanka @ACJUNEWS @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට යුර?
# 6  @WHOSriLanka @UNSriLanka @WHOSEARO @WHO @MoH_SriLanka @HPBSriLanka @RajapaksaNamal @MCND_LKA @newsdotlk කරැනාකර චිනයේ නිෂ්පාදිත Sinopharm එන්නත ලබාගත් පුද්ගලයන් හට ය?
#
#         CREATED_AT LIKE COUNT FOLLOWERS COUNT     LABEL  \
# 2   7/29/2021 2:40          1            1433     Other
# 3  7/27/2021 10:40         10           13898  Politics
# 4  7/25/2021 20:56          0              87     Other
# 5  7/25/2021 20:53          0              87     Other
# 6  7/25/2021 20:52          1              87     Other
#
#                                                                                 cleaned_msg  \
# 2        හාමුදුරුවරුන්ගේ සහ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය ගැන සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3  ද්විපාර්ශවික එකඟතාව පරිදි ජන ජීවිත සහ සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය හා
# 4         කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                                     කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                       කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට ය
#
#                                                                      remove_stopword  \
# 2        හාමුදුරුවරුන්ගේ සියලූම පූජකයන්ගේ මානසික සෞඛ්යය සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3       ද්විපාර්ශවික එකඟතාව ජන ජීවිත සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය
# 4  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                              කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                  කරැනාකර චිනයේ නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට
#
#                                                                     stemming_words
# 2          හාමුදුරුවරු සියලූම පූජකයන්ගේ මානසික සෞඛ්යය සොයා බැලීමේ වැඩ පිලිවලක් ඕනේ
# 3      ද්විපාර්ශවික එකඟතා ජන ජීවිත සෞඛ්යය මනාව ආරක්ෂා කරමින් හැකි ඉක්මණින් ආර්ථිකය
# 4  කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුරෝපීය රට වලට විසා නිකුත් නොකි
# 5                              කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට යුර
# 6                                  කරැනාකර චින නිෂ්පාදිත එන්නත ලබාගත් පුද්ගලයන් හට

# %%
df = pd.DataFrame(data, columns= ['User', 'CREATED_AT','LABEL','stemming_words','LIKE COUNT','FOLLOWERS COUNT'])
df.to_csv("FinalListPreprocessedData.csv")

# %%
#################################Linear regression classification #######################################

# %%
data['LABEL'].value_counts()
# Out:
# Other            186
# Politics         130
# Crime            109
# Sport             93
# Entertainment     15
# Name: LABEL, dtype: int64

# %%
data.shape
# Out:
# (533, 10)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv1 = CountVectorizer()
x = cv1.fit_transform(data['stemming_words'])

# %%
print(x.shape)
# Out:
# (533, 1081)

# %%
x[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,data['LABEL'], test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score # mectric that use

# %%
#training
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
review = 'අන්තර්ජාලය ඔස්සේ අළෙවි වූ බාලවයස්කාර දැරිය අපයෝජනය කිරීමේ කාන්තා'
commenttype = model.predict(cv1.transform([review]))[0]
if commenttype=='Crime':
    print('Crime Comment')
elif commenttype=='Sport':
     print('Sport Comment')
else:
    print('Other Comment')
# Out:
# Crime Comment

# %%
csvfile = open('FinalListPreprocessedData.csv', encoding="utf-8")
lines= len(csvfile.readlines())
print(lines)
# Out:
# 534
